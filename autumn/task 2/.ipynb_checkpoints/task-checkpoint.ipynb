# %% [markdown]
# # Машинное обучение, ВМК МГУ
#
# ## Практическое задание 2. Exploratory Data Analysis и линейная регрессия
#
# ### Общая информация
# Дата выдачи: 08.10.2021
#
# Мягкий дедлайн: 23:59MSK 22.10.2021
#
# Жесткий дедлайн: 23:59MSK 29.10.2021

# %% [markdown]
# ### О задании
# В этом задании мы попытаемся научиться анализировать данные и выделять из них полезные признаки. Мы также будем использовать `seaborn` и научимся `sklearn`, а заодно привыкнем к основным понятиям машинного обучения.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — **12 баллов + 4.8 бонусов**. Проверяющий имеет право снизить оценку за неэффективную реализацию или неопрятные графики.
#
# **Обратите внимание**, что в каждом разделе домашнего задания есть оцениваниемые задачи и есть вопросы. Вопросы дополняют задачи и направлены на то, чтобы проинтерпретировать или обосновать происходящее. Код без интерпретации не имеет смысла, поэтому отвечать на вопросы обязательно — за отсутствие ответов мы будем снижать баллы за задачи. Если вы ответите на вопросы, но не напишете корректный код к соответствующим оцениваемым задачам, то баллы за такое выставлены не будут.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# <p style="color:#de3815;font-size:25px;">
# Напоминание об оформлении и выполнении ноутбука
# </p>
#
# * Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть, не запуская ячейки (кроме редких случаев, когда необходимо намеренно скрыть ненужный output, про такие случаи желательно писать пояснения в тексте). **В противном случае -1 балл**
# * При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. **Не нужно** удалять и видоизменять написанный код и текст, если явно не указана такая возможность. Создавать новые ячейки с кодом/текстов там, где это осмысленно и вы считаете необходимым, конечно, можно. **В противном случае -1 балл**
# * В anytask обязательно нужно прикреплять отдельно файл с расширением ipynb (не в архиве, а именно отдельно). Если необходимо отправить еще какие-то файлы, то вынесите их в отдельный архив (если файлов много) и пришлите. **В противном случае -0.5 балла**
# ---
# * Пишите, пожалуйста, выводы и ответы на вопросы в текстовых ячейках/при помощи print в коде/как результат вывода ячейки. При их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и **поэтому будем снижать баллы**
# * Если алгоритм не сказано реализовывать явно, его всегда можно импортировать из библиотеки.
# ---
# * Про графики. _Штрафы будут применяться к каждому результату команды отображения графика (plt.show() и др. аналогичные). Исключением являются графики, генерируемые функциями каких-либо сторонних библиотек, если их нельзя кастомизировать_
#
#     * должно быть название (plt.title) графика; **В противном случае &ndash; -0.05 балла**
#     * на графиках должны быть подписаны оси (plt.xlabel, plt.ylabel); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * должны быть подписаны единицы измерения (если это возможно); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * все названия должны быть понятны любому человеку, знакомому с терминологией, без заглядывания в код; **В противном случае &ndash; -0.05 балла**
#     * подписи тиков на осях не должны сливаться как на одной оси, так и между ними; **В противном случае &ndash; -0.025 балла за каждую ось**
#     * если изображено несколько сущностей на одном холсте (например несколько функций), то необходима поясняющая легенда (plt.legend); **В противном случае &ndash; -0.05 балла**
#     * все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном); **В противном случае &ndash; -0.05 балла**
#     * если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
#     * графики должны быть не супер-микро и не супер-макро по размерам, так, чтобы можно было увидеть все, что нужно.
#     * при необходимости улучшения наглядности графиков, можно пользоваться логарифмической шкалой по осям x/y.
#
# ### А также..
#
# * Для удобства поиска вопросов, на которые от вас просят ответа, мы пометили их знаком **(?)**
# * Знак **(!)** означает, что выполнение замечания необходимо для **возможности получения полного балла**
# * Даем до +0.5 баллов за выдающиеся успехи по субъективному мнению проверяющих. Этот **бонус** не апеллируется

# %% [markdown]
# В этом ноутбуке используется библиотека `folium` для визуализации карт. Она работает в google colab!

# %%
# !pip3 install folium

# %%
import folium

m = folium.Map(location=(55.7522200, 37.6155600), zoom_start=10)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Если вы всё сделали правильно, то выше должна открыться карта Москвы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="darkgrid")

# %% [markdown]
# ## Часть 0. Подготовка (1 балл)

# %% [markdown]
# **Задание 1 (1 балл)**.
#
# Мы будем работать с данными из соревнования [New York City Taxi Trip Duration](https://www.kaggle.com/c/nyc-taxi-trip-duration/overview), в котором нужно было предсказать длительность поездки на такси. Скачайте обучающую выборку из этого соревнования и загрузите ее:

# %%
X = pd.read_csv('train.csv')
X.head(5)
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# ...

# %% [markdown]
# **(0.1 балл)** Обратите внимание на колонки `pickup_datetime` и `dropoff_datetime`. `dropoff_datetime` был добавлена организаторами только в обучающую выборку, то есть использовать эту колонку нельзя, давайте удалим ее. В `pickup_datetime` записаны дата и время начала поездки. Чтобы с ней было удобно работать, давайте преобразуем даты в `datetime`-объекты

# %%
X['pickup_datetime'] = pd.to_datetime(X['pickup_datetime'])
X = X.drop(['dropoff_datetime'], axis = 1)

# %% [markdown]
# **(0.2 балла)** В колонке `trip_duration` записано целевое значение, которое мы хотим предсказывать. Давайте посмотрим на распределение таргета в обучающей выборке. Для этого нарисуйте его гистограмму:

# %%
plt.figure(figsize=(10, 7))
plt.title('Гистограмма распределения trip_duration')
plt.hist(X['trip_duration'], bins=100)
plt.xlabel('duration')
plt.ylabel('number of train records')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)**Что можно сказать о целевой переменной по гистограмме её значений?

# %% [markdown]
# **Ответ**: Можно заметить, что в нашей выборке присутствует несколько выбросов, в которых время поездки было очень большим. Возможно это связано с техническими проблемами(неисправность работы счётчика) или с несвоевременным отключением прибора.

# %% [markdown]
# В соревновании в качестве метрики качества использовалось RMSLE:
# $$\text{RMSLE}(X, y, a) = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{(y_i + 1)} - \log{(a(x_i) + 1)}\big)^2}$$
#
# **Вопрос (0.1 балл)**: **(?)**Как вы думаете, почему авторы соревнования выбрали именно RMSLE, а не RMSE?

# %% [markdown]
# **Ответ**: RMSE очень неустойчив к выбросам. При их появлении RMSE становится очень большим. В это же время RMSLE надёжен к выбросам. При их появлении RMSLE становится значительно меньше, чем RMSE. К тому же, благодаря свойствам логрифма, RMSLE можно рассматривать, как относительную ошибку предсказания от действительного значения. Также RMSLE делает большой штраф за недооценку предсказания, чем за завышение.

# %% [markdown]
# На семинаре мы рассматривали несколько моделей линейной регрессии в `sklearn`, но каждая из них оптимизировала среднеквадратичную ошибку (MSE), а не RMSLE. Давайте проделаем следующий трюк: будем предсказывать не целевую переменную, а ее *логарифм*. Обозначим $\hat{y}_i = \log{(y_i + 1)}$ — модифицированный таргет, а $\hat{a}(x_i)$ — предсказание модели, которая обучалась на $\hat{y}_i$, то есть логарифм таргета. Чтобы предсказать исходное значение, мы можем просто взять экспоненту от нашего предсказания: $a(x_i) = \exp(\hat{a}(x_i)) - 1$.
#
# **Вопрос (0.3 балла)**: **(?)**Покажите, что оптимизация RMSLE для модели $a$ эквивалентна оптимизации MSE для модели $\hat{a}$.
#
# **Доказательство**: Напишие прямо тут в ячейке, при необходимости использовав синтаксис LaTeX в ячейке
#
# MSE для модели $\hat{a}$: $\text{MSE}(X, \hat{y}, \hat{a}) = \frac{1}{\ell}\sum_{i=1}^{\ell} \big(\hat{y}_i - \hat{a}(x_i)\big)^2$\
# RMSLE для модели $a$: $\text{RMSLE}(X, y, a) = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{(y_i + 1)} - \log{(a(x_i) + 1)}\big)^2}$
#
# Если мы приравняем к нулю оба уравнения(т.к. это минимум данных функций), то из первого получим:
# $\hat{a}(x_i) = \hat{y}_i = \log{(y_i + 1)}$
#
# А из второго:
# $\log{(y_i + 1)} = \log{(a(x_i) + 1)} = \log{(\exp(\hat{a}(x_i)) - 1 + 1)} = \hat{a}(x_i)$
#
# Отсюда и следует, что оптимизация RMSLE для модели $a$ эквивалентна оптимизации MSE для модели $\hat{a}$.

# %% [markdown]
# **(0.1 балл)** Итак, мы смогли свести задачу оптимизации RMSLE к задаче оптимизации MSE, которую мы умеем решать! Кроме того, у логарифмирования таргета есть еще одно полезное свойство. Чтобы его увидеть, добавьте к нашей выборке колонку `log_trip_duration` (воспользуйтесь `np.log1p`) и нарисуйте гистограмму модифицированного таргета по обучающей выборке. Удалите колонку со старым таргетом.

# %%
X['log_trip_duration'] = np.log1p(X['trip_duration'])
X = X.drop(['trip_duration'], axis = 1)
X.head(5)
# Out:
#           id  vendor_id     pickup_datetime  passenger_count  \
# 0  id2875421          2 2016-03-14 17:24:55                1
# 1  id2377394          1 2016-06-12 00:43:35                1
# 2  id3858529          2 2016-01-19 11:35:24                1
# 3  id3504673          2 2016-04-06 19:32:31                1
# 4  id2181028          2 2016-03-26 13:30:55                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.982155        40.767937         -73.964630         40.765602
# 1        -73.980415        40.738564         -73.999481         40.731152
# 2        -73.979027        40.763939         -74.005333         40.710087
# 3        -74.010040        40.719971         -74.012268         40.706718
# 4        -73.973053        40.793209         -73.972923         40.782520
#
#   store_and_fwd_flag  log_trip_duration
# 0                  N           6.122493
# 1                  N           6.498282
# ...

# %%
plt.figure(figsize=(10, 7))
plt.title('Гистограмма распределения log_trip_duration', fontsize=15)
plt.hist(X['log_trip_duration'], bins=100)
plt.xlabel('log(trip_duration)', fontsize=15)
plt.ylabel('number of train records', fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# **(0.1 балл)** Чтобы иметь некоторую точку отсчета, давайте посчитаем значение метрики MSE при наилучшем константном предсказании:

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred = np.ones(len(X['log_trip_duration'])) * X['log_trip_duration'].mean()
mean_squared_error(y_pred, X['log_trip_duration'], squared=True)
# Out:
# 0.6332327625405546

# %% [markdown]
# ## Часть 1. Изучаем `pickup_datetime` (4 балла)
#
# **Задание 2 (0.5 баллов)**.
#
# **(0.25 баллов)** Для начала давайте посмотрим, сколько всего было поездок в каждый из дней. Постройте график зависимости количества поездок от дня в году (например, можно воспользоваться `sns.countplot`):

# %%
days, counts = np.unique(X['pickup_datetime'].dt.dayofyear, return_counts = True)

plt.figure(figsize=(10, 7))
plt.plot(days, counts, color='r')

plt.grid(True) 

plt.title('Зависимость количества поездок от дня в году', fontsize=17)
plt.ylabel('Количество поездок', fontsize=17)
plt.xlabel('День в году', fontsize=17)

plt.show()

# %% [markdown]
# Вы, вероятно, заметили, что на графике есть 2 периода с аномально маленькими количествами поездок.
#
# **(0.1 балл**)Вычислите, в какие даты происходили эти скачки вниз и найдите информацию о том, что происходило в эти дни в Нью-Йорке.

# %%
day_min_1 = days[np.argmin(counts)]
counts = np.delete(counts, np.argmin(counts))
days = np.delete(days, np.argmin(counts))
counts = np.delete(counts, np.argmin(counts))
days = np.delete(days, np.argmin(counts))
day_min_2 = days[np.argmin(counts)]
day_min_1, day_min_2
# Out:
# (23, 151)

# %%
import datetime
date_1 = datetime.date(2016, 1, 1) + datetime.timedelta(days=int(day_min_1 - 1))
date_2 = datetime.date(2016, 1, 1) + datetime.timedelta(days=int(day_min_2 - 1))
date_1, date_2
# Out:
# (datetime.date(2016, 1, 23), datetime.date(2016, 5, 30))

# %% [markdown]
# **Ответ**: Упадок количества поездок наблюдался на 23, 24 и на 151 дни в году. Это 23.01.2016 и 30.05.2016. 24 января Власти запретили автомобильное движение в Нью-Йорке из-за снежной бури. А 30 мая празновали День Памяти.

# %% [markdown]
# **(0.15 баллов)** Нарисуйте графики зависимости количества поездок от дня недели и от часов в сутках (воспользуйтесь `sns.relplot`):

# %%
days, counts_days = np.unique(X['pickup_datetime'].dt.weekday, return_counts = True)
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sns.set_style('whitegrid')
df = pd.DataFrame({'days': days, 'counts' : counts_days})

sns.relplot(data=df, x='days', y='counts', height=7, aspect=1)
plt.title('Зависимость количества поездок от дня недели', fontsize=15)
plt.xlabel('День недели', fontsize=15)
plt.ylabel('Количество поездок', fontsize=15)
plt.show()

# %%
hours, counts_hours = np.unique(X['pickup_datetime'].dt.hour, return_counts = True)
sns.set_style('whitegrid')
df = pd.DataFrame({'hours': hours, 'counts' : counts_hours})
sns.relplot(data=df, x='hours', y='counts', kind="line", height=6, aspect=1.3)
plt.title('Зависимость количества поездок от часа в сутках', fontsize=15)
plt.xlabel('Часы в сутках', fontsize=15)
plt.ylabel('Количество поездок', fontsize=15)
plt.show()

# %% [markdown]
# **Задание 3 (1 балл)**.
#
# * **(0.3 балла)** Нарисуйте на одном графике зависимости количества поездок от часа в сутках для разных месяцев (разные кривые, соответствующие разным месяцам, окрашивайте в разные цвета, воспользуйтесь `hue` в `sns.relplot`).
# * **(0.3 балла)** Аналогично нарисуйте зависимости количества поездок от часа в сутках для разных дней недели.

# %%
months = np.unique(X['pickup_datetime'].dt.month)
m = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df = pd.DataFrame()
for month in months:
    hours, counts_hours = np.unique(X[X['pickup_datetime'].dt.month == month]['pickup_datetime'].dt.hour, return_counts = True)
    for i in range(len(hours)):
        df = df.append({'hours': hours[i], 'counts': counts_hours[i], 'month': m[month-1]}, ignore_index=True)

sns.relplot(data=df, x='hours', y='counts', kind="line", hue="month", height=6, aspect=1.3)
plt.title('Зависимость количества поездок от часа в сутках по месяцам', fontsize=15)
plt.xlabel('Часы в сутках', fontsize=15)
plt.ylabel('Количество поездок', fontsize=15)
plt.show()

# %%
d = np.unique(X['pickup_datetime'].dt.weekday)
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df = pd.DataFrame()
for day in d:
    hours, counts_days = np.unique(X[X['pickup_datetime'].dt.weekday == day]['pickup_datetime'].dt.hour, return_counts = True)
    for i in range(len(hours)):
        df = df.append({'hours': hours[i], 'counts': counts_days[i], 'weekday': days[day-1]}, ignore_index=True)

sns.relplot(data=df, x='hours', y='counts', kind="line", hue="weekday", height=6, aspect=1.3)
plt.title('Зависимость количества поездок от часа в сутках по дням недели', fontsize=15)
plt.xlabel('Часы в сутках', fontsize=15)
plt.ylabel('Количество поездок', fontsize=15)
plt.show()

# %% [markdown]
# **Вопрос  (0.4 балла)**: **(?)** Какие выводы можно сделать, основываясь на графиках выше? Выделяются ли какие-нибудь дни недели? Месяца? Время суток? С чем это связано?

# %% [markdown]
# **Ответ**: Можно заметить, что количество поездок резко падает ночью, когда все спят. Утром и днём их число увеличивается, когда многие едут на работу или по делам, связанным с ней. Количество поездок резко возрастает вечером, когда все возвращаются домой. Утром их не такое же количество, т.к. возможно у многих работа начинается в разное время, а заканчивается примерно в одно и то же.\
# Видно, что количество поездок практически никак не зависит от месяца. Можно лишь пронаблюдать, что в июне и январе их чуть меньше. Это может быть связано с тем, что в июне многие уезжают в отпуск, а в январе заснеженные скользкие дороги и некоторые не хотят рисковать по ним ездить.\
# Также можно увидеть, что меньше всего поездок в понедельник и воскресенье, а больше всего с четверга по субботу. Это можно объяснить тем, что воскресенье является выходным днём, а за ним едёт рабочий день, поэтому количество поездок меньше, т.к. большинство людей сидит дома и готовиться с будням. Пик поездок приходится на пятницу. В первой половине люди ездят по работе, а во второй, т.к. последующие дни выходные, в гости, гулять и т.д. Так же можно заметить, что в пятницу и субботу намного больше ночных поездок, когда все возвращаются домой после гулянок.

# %% [markdown]
# **Задание 4 (1 балл)**.
#
# **(0.1 балл) за каждый пункт**
# * Разбейте выборку на обучающую и тестовую в отношении 7:3.
# * По обучающей выборке нарисуйте график зависимости среднего логарифма времени поездки от дня недели.
# * Затем сделайте то же самое, но для часа в сутках и дня в году.

# %%
from sklearn.model_selection import train_test_split

y = X["log_trip_duration"]
X = X.drop(columns=["log_trip_duration"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
log_mean = []
for day in range(7):
    log_mean.append(np.mean(y_train[X_train['pickup_datetime'].dt.weekday == day]))
    
plt.figure(figsize=(10, 7))
plt.plot(days, log_mean)

plt.grid(True) 

plt.title('Зависимость среднего логарифма времени поездки от дня недели', fontsize=13)
plt.ylabel('Логарифм времени поездки', fontsize=13)
plt.xlabel('День недели', fontsize=13)

plt.show()

# %%
hours = np.arange(24)
log_mean = []
for hour in hours:
    log_mean.append(np.mean(y_train[X_train['pickup_datetime'].dt.hour == hour]))
    
plt.figure(figsize=(10, 7))
plt.plot(hours, log_mean)

plt.grid(True) 

plt.title('Зависимость среднего логарифма времени поездки от часа в сутках', fontsize=13)
plt.ylabel('Логарифм времени поездки', fontsize=13)
plt.xlabel('Часы', fontsize=13)

plt.show()

# %%
days = np.unique(X_train['pickup_datetime'].dt.dayofyear)
log_mean = []
for day in days:
    log_mean.append(np.mean(y_train[X_train['pickup_datetime'].dt.dayofyear == day]))
    
plt.figure(figsize=(10, 7))
plt.plot(days, log_mean)

plt.grid(True) 

plt.title('Зависимость среднего логарифма времени поездки от дня в году', fontsize=13)
plt.ylabel('Логарифм времени поездки', fontsize=13)
plt.xlabel('День в году', fontsize=13)

plt.show()

# %% [markdown]
# **Вопрос (0.3 балла)**: **(?)**Похожи ли графики зависимости таргета от дня недели и от часа в сутках на аналогичные графики для количества поездок? Почему? Что происходит со средним таргетом в те два аномальных периода, что мы видели выше? Почему так происходит? Наблюдаете ли вы какой-нибудь тренд на графике зависимости `log_trip_duration` от номера дня в году?

# %% [markdown]
# **Ответ**: Графики зависимости таргета и количества поездок примерно одинаковы. График от дня в году в обоих случаях похож на кардиограмму человека, пробежавшего марафон. Это может быть связано с тем, что в будние дни увеличивается количичество поездок. Что приводит к росту числа машин. Следовательно возникают пробки и тем самым увеличивает время поездки. А на выходных количество поездок уменьшается, дороги становятся свободнее. Значит и время пути уменьшается. Что мы и наблюдаем на первом графике. Именно поэтому последний график, то увеличивается, то уменьшается. Видно, что в те 2 аномальных дня у нас возникают особенные изломы на графике таргета. Также можно пронаблюдать, что если построить усредняющую функцию зависимости таргета от дня в году, то она будет линейной.\
# На графике времени поездки от часа мы можем заметить, что дольше всего поездки длятся днём, в период пробок. А ночью, когда дороги свободны, таргет резко становится меньше. Собственно та же зависимоть наблюдается и на графике количества поездок.

# %% [markdown]
# **(0.1 балл)**
# Добавьте следующие признаки на основе `pickup_datetime`:
# 1. День недели
# 2. Месяц
# 3. Час
# 4. Является ли период аномальным (два бинарных признака, соответствующие двум аномальным периодам)
# 5. Номер дня в году

# %%
def func_weekdays(idx):
    return days[idx]

def func_months(idx):
    return months[idx - 1]

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

X_train = X_train[:]
X_train['dayofyear_trip'] = X_train['pickup_datetime'].dt.dayofyear
X_train['weekday_trip'] = X_train['pickup_datetime'].dt.weekday.apply(func_weekdays)
X_train['hour_trip'] = X_train['pickup_datetime'].dt.hour
X_train['month_trip'] = X_train['pickup_datetime'].dt.month.apply(func_months)

mask1_1 = 22 <= X_train.dayofyear_trip
mask1_2 = X_train.dayofyear_trip <= 24
mask1 = mask1_1 & mask1_2
mask2_1 = 150 <= X_train.dayofyear_trip
mask2_2 = X_train.dayofyear_trip <= 152
mask2 = mask2_1 & mask2_2
X_train.loc[mask1, 'abnormal_day_1'] = 1
X_train.loc[~mask1, 'abnormal_day_1'] = 0
X_train['abnormal_day_1'] = X_train['abnormal_day_1'].astype(int)
X_train.loc[mask2, 'abnormal_day_2'] = 1
X_train.loc[~mask2, 'abnormal_day_2'] = 0
X_train['abnormal_day_2'] = X_train['abnormal_day_2'].astype(int)
X_train
# Out:
#                 id  vendor_id     pickup_datetime  passenger_count  \
# 824746   id2365163          2 2016-03-27 00:25:29                3
# 645821   id3126187          2 2016-03-18 20:44:12                1
# 691846   id2588127          2 2016-04-15 18:26:12                2
# 1147931  id0915715          2 2016-03-24 14:28:34                1
# 183569   id3758776          1 2016-04-28 13:53:52                1
# ...            ...        ...                 ...              ...
# 1348317  id2763967          1 2016-05-12 05:16:06                1
# 1154171  id0853058          1 2016-01-16 19:14:54                1
# 617841   id2242904          1 2016-03-21 20:11:12                1
# 1048548  id2558617          1 2016-04-09 09:21:44                1
# 1393929  id3799449          1 2016-04-27 09:11:19                1
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 824746         -73.996986        40.742210         -73.987740
# ...

# %%
X_test = X_test[:]
X_test['dayofyear_trip'] = X_test['pickup_datetime'].dt.dayofyear
X_test['weekday_trip'] = X_test['pickup_datetime'].dt.weekday.apply(func_weekdays)
X_test['hour_trip'] = X_test['pickup_datetime'].dt.hour
X_test['month_trip'] = X_test['pickup_datetime'].dt.month.apply(func_months)

mask1_1 = 22 <= X_test.dayofyear_trip
mask1_2 = X_test.dayofyear_trip <= 24
mask1 = mask1_1 & mask1_2
mask2_1 = 150 <= X_test.dayofyear_trip
mask2_2 = X_test.dayofyear_trip <= 152
mask2 = mask2_1 & mask2_2
X_test.loc[mask1, 'abnormal_day_1'] = 1
X_test.loc[~mask1, 'abnormal_day_1'] = 0
X_test['abnormal_day_1'] = X_test['abnormal_day_1'].astype(int)
X_test.loc[mask2, 'abnormal_day_2'] = 1
X_test.loc[~mask2, 'abnormal_day_2'] = 0
X_test['abnormal_day_2'] = X_test['abnormal_day_2'].astype(int)
X_test
# Out:
#                id  vendor_id     pickup_datetime  passenger_count  \
# 112342  id2631171          2 2016-01-23 00:09:14                1
# 840803  id2892416          1 2016-02-10 19:24:14                3
# 184538  id3095142          2 2016-05-12 06:39:26                1
# 512001  id3803823          2 2016-01-21 08:31:03                1
# 776055  id3155730          2 2016-01-02 13:12:33                2
# ...           ...        ...                 ...              ...
# 846197  id1951185          1 2016-01-09 23:00:55                4
# 85559   id1088375          2 2016-06-02 15:06:24                1
# 940126  id1422099          1 2016-05-02 09:51:23                1
# 643278  id2188597          2 2016-04-06 09:28:59                1
# 151807  id0184885          1 2016-03-17 16:22:00                1
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 112342        -74.006615        40.731712         -73.991890
# ...

# %% [markdown]
# Итак, мы уже создали некоторое количество признаков.
#
# **Вопрос (0.3 балла)**: **(?)**Какие из признаков стоит рассматривать как категориальные, а какие - как численные? Почему?

# %% [markdown]
# **Ответ**: Категориальные признаки - признаки, на которых нельзя задать порядок, который имел бы смысл. Поэтому в задании все добавленные признаки категориальные.

# %% [markdown]
# **Задание 5 (1.5 балла)**. Обучите `Ridge`-регрессию с параметрами по умолчанию, закодировав все категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`. Используйте только признаки, которые мы выделили в этой части задания.

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
numeric_features = []
categorical = ['weekday_trip', 'month_trip', 'abnormal_day_1', 'abnormal_day_2', 'dayofyear_trip', 'hour_trip']

# %%
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

# %%
model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSLE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSLE = 0.6258

# %% [markdown]
# ## Часть 2. Изучаем координаты (3 балла)
# Мы уже очень хорошо изучили данные о времени начала поездки, давайте теперь посмотрим на информацию о координатах начала и конца поездки. Мы подготовили для вас функцию, которая на карте рисует точки начала или конца поездки. Примеры ее вызова вы найдете ниже. Обратите внимание, что в эту функцию мы передаем лишь небольшой кусочек данных, посколько иначе функция будет работать очень долго

# %%
def show_circles_on_map(data, latitude_column, longitude_column, color):
    """
    The function draws map with circles on it.
    The center of the map is the mean of coordinates passed in data.
    
    data: DataFrame that contains columns latitude_column and longitude_column
    latitude_column: string, the name of column for latitude coordinates
    longitude_column: string, the name of column for longitude coordinates
    color: string, the color of circles to be drawn
    """

    location = (data[latitude_column].mean(), data[longitude_column].mean())
    m = folium.Map(location=location)

    for _, row in data.iterrows():
        folium.Circle(
            radius=100,
            location=(row[latitude_column], row[longitude_column]),
            color=color,
            fill_color=color,
            fill=True
        ).add_to(m)

    return m

# %%
show_circles_on_map(X.sample(1000), "pickup_latitude", "pickup_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
show_circles_on_map(X.sample(1000), "dropoff_latitude", "dropoff_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# **Вопрос**: Какие две точки выделяются на карте?

# %% [markdown]
# **Ответ**: вдали от Манхэттена выделяютя 2 аэропорта - John F. Kennedy International Airport и LaGuardia Airport.

# %% [markdown]
# **Задание 6 (0.75 балл)**.
#
# **(0.3 балла)** Как мы все прекрасно помним, $t = s / v_{\text{ср}}$, поэтому очевидно, что самым сильным признаком будет расстояние, которое необходимо проехать. Мы не можем посчитать точное расстояние, которое необходимо преодолеть такси, но мы можем его оценить, посчитав кратчайшее расстояние между точками начала и конца поездки. Чтобы корректно посчитать расстояние между двумя точками на Земле, можно использовать функцию `haversine`. Посчитайте кратчайшее расстояние для объектов и запишите его в колонку `haversine`:

# %%
from haversine import haversine_vector

start = np.hstack((np.array(X_train['pickup_latitude']).reshape(-1, 1), np.array(X_train['pickup_longitude']).reshape(-1, 1)))
finish = np.hstack((np.array(X_train['dropoff_latitude']).reshape(-1, 1), np.array(X_train['dropoff_longitude']).reshape(-1, 1)))
X_train['haversine'] = haversine_vector(start, finish)
X_train
# Out:
#                 id  vendor_id     pickup_datetime  passenger_count  \
# 824746   id2365163          2 2016-03-27 00:25:29                3
# 645821   id3126187          2 2016-03-18 20:44:12                1
# 691846   id2588127          2 2016-04-15 18:26:12                2
# 1147931  id0915715          2 2016-03-24 14:28:34                1
# 183569   id3758776          1 2016-04-28 13:53:52                1
# ...            ...        ...                 ...              ...
# 1348317  id2763967          1 2016-05-12 05:16:06                1
# 1154171  id0853058          1 2016-01-16 19:14:54                1
# 617841   id2242904          1 2016-03-21 20:11:12                1
# 1048548  id2558617          1 2016-04-09 09:21:44                1
# 1393929  id3799449          1 2016-04-27 09:11:19                1
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 824746         -73.996986        40.742210         -73.987740
# ...

# %%
start = np.hstack((np.array(X_test['pickup_latitude']).reshape(-1, 1), np.array(X_test['pickup_longitude']).reshape(-1, 1)))
finish = np.hstack((np.array(X_test['dropoff_latitude']).reshape(-1, 1), np.array(X_test['dropoff_longitude']).reshape(-1, 1)))
X_test['haversine'] = haversine_vector(start, finish)

# %% [markdown]
# **(0.25 балла)** Так как мы предсказываем логарифм времени поездки и хотим, чтобы наши признаки были линейно зависимы с этой целевой переменной, нам нужно логарифмировать расстояние: $\log t = \log s - \log{v_{\text{ср}}}$. Запишите логарифм `haversine` в отдельную колонку:

# %%
X_train['log_haversine'] = np.log1p(X_train['haversine'])
X_test['log_haversine'] = np.log1p(X_test['haversine'])

# %% [markdown]
# **(0.2 балла)** Убедимся, что логарифм расстояния лучше коррелирует с нашим таргетом, чем просто расстояние:

# %%
correlations = X_train[['haversine', 'log_haversine']].corrwith(y_train).sort_values(ascending=False)
plot = sns.barplot(y=correlations.index, x=correlations)
plot.figure.set_size_inches(10, 5)

# %% [markdown]
# **Задание 7 (0.75 балла)**.
#
# **(0.2 балла)** Давайте изучим среднюю скорость движения такси. Посчитайте среднюю скорость для каждого объекта обучающей выборки, разделив `haversine` на `trip_duration`, и нарисуйте гистограмму ее распределения

# %%
plt.figure(figsize=(10, 7))
plt.title('Гистограмма распределения средней скорости', fontsize=15)
plt.hist(X_train['haversine'] * 3600/ (np.exp(y_train) - 1), bins=100)
plt.xlabel('Средняя скорость', fontsize=15)
plt.ylabel('number of train records', fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# **(0.1 балл)** Как можно видеть по гистограмме, для некоторых объектов у нас получились очень больше значения скоростей. Нарисуйте гистограмму по объектам, для которых значение скорости получилось разумным (например, можно не включать рассмотрение объекты, где скорость больше некоторой квантили):

# %%
plt.figure(figsize=(10, 7))
plt.title('Гистограмма распределения средней скорости', fontsize=15)
v_mean = X_train['haversine'] * 3600/ (np.exp(y_train) - 1)
mask = (v_mean < np.quantile(v_mean, 0.98))
plt.hist(v_mean[mask], bins=100)
plt.xlabel('Средняя скорость без выбросов', fontsize=15)
plt.ylabel('number of train records', fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# **(0.1 балл)** Для каждой пары (день недели, час суток) посчитайте медиану скоростей. Нарисуйте с помощью `sns.heatmap` график, где по осям будут дни недели и часы, а в качестве значения функции - медиана скорости

# %%
X_train['speed'] = X_train['haversine'] * 3600/ (np.exp(y_train) - 1)
df = X_train.groupby(by=['weekday_trip', 'hour_trip'])['speed'].median()
days = np.unique(X_train['weekday_trip'])
days =  [d for d in days for i in range(24)]
hours = list(np.arange(24))*7
df = pd.DataFrame(list(zip(days, hours, df)), columns = ['weekday_trip', 'hour_trip', 'speed'])
df = df.pivot(index="weekday_trip", columns="hour_trip", values="speed")

plt.figure(figsize=(10, 7))
plt.title('Зависимость скорости от времени и дня недели', fontsize=15)
sns.heatmap(df)

# %%
X_train = X_train.drop(columns=["speed"])

# %% [markdown]
# Не забудьте удалить колонку со значением скорости из данных!
#
# **Вопрос (0.1 балл)**: **(?)** Почему значение скорости нельзя использовать во время обучения?

# %% [markdown]
# **Ответ**: Потому что время поездки напрямую выражается через расстояние и скорость. Наша модель увидит эту зависимость и обнулит все веса кроме этих двух. К тому же скорость мы получили, зная время. В тестовой выборке мы не знаем времени, следовательно не можем вычислить скорость. Поэтому мы не сможем добавить этот признак в тестовую выборку, а следовательно признаковое пространство обучающей и тестовой выборки будет разным.

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)** Посмотрите внимательно на график и скажите, в какие моменты времени скорость минимальна; максимальна.

# %% [markdown]
# **Ответ**: Скорость минимальна по будням примерно с 8 утра и до 19. А также в субботу вечером. А максимальна рано утром в 4-5 и в воскресенье около 6 утра.

# %% [markdown]
# **(0.15 балл)** Создайте признаки "поездка совершается в период пробок" и "поездка совершается в период свободных дорог" (естественно, они не должен зависеть от скорости!):

# %%
mask1 = ((X_train['weekday_trip'] == 'Monday') | (X_train['weekday_trip'] == 'Tuesday') |\
         (X_train['weekday_trip'] == 'Friday') | (X_train['weekday_trip'] == 'Wednesday') |\
         (X_train['weekday_trip'] == 'Thursday')) & X_train['hour_trip'].between(7, 20, inclusive=False)

mask2 = (X_train['weekday_trip'] == 'Saturday') & X_train['hour_trip'].between(18, 20, inclusive=True)
mask = mask1 | mask2
X_train.loc[mask, 'traffic'] = 1
X_train.loc[~mask, 'traffic'] = 0
X_train['traffic'] = X_train['traffic'].astype(int)

# %%
mask1 = ((X_test['weekday_trip'] == 'Monday') | (X_test['weekday_trip'] == 'Tuesday') |\
         (X_test['weekday_trip'] == 'Friday') | (X_test['weekday_trip'] == 'Wednesday') |\
         (X_test['weekday_trip'] == 'Thursday')) & X_test['hour_trip'].between(8, 19, inclusive=True)

mask2 = (X_test['weekday_trip'] == 'Saturday') & X_test['hour_trip'].between(18, 20, inclusive=True)
mask = mask1 | mask2
X_test.loc[mask, 'traffic'] = 1
X_test.loc[~mask, 'traffic'] = 0
X_test['traffic'] = X_test['traffic'].astype(int)

# %%
mask1 = ((X_train['weekday_trip'] == 'Monday') | (X_train['weekday_trip'] == 'Tuesday') |\
         (X_train['weekday_trip'] == 'Friday') | (X_train['weekday_trip'] == 'Wednesday') |\
         (X_train['weekday_trip'] == 'Thursday')) & X_train['hour_trip'].between(4, 5, inclusive=True)

mask2 = ((X_train['weekday_trip'] == 'Saturday') | (X_train['weekday_trip'] == 'Sunday')) &\
        X_train['hour_trip'].between(5, 6, inclusive=True)
mask = mask1 | mask2
X_train.loc[mask, 'free'] = 1
X_train.loc[~mask, 'free'] = 0
X_train['free'] = X_train['free'].astype(int)

# %%
mask1 = ((X_test['weekday_trip'] == 'Monday') | (X_test['weekday_trip'] == 'Tuesday') |\
         (X_test['weekday_trip'] == 'Friday') | (X_test['weekday_trip'] == 'Wednesday') |\
         (X_test['weekday_trip'] == 'Thursday')) & X_test['hour_trip'].between(4, 5, inclusive=True)

mask2 = ((X_test['weekday_trip'] == 'Saturday') | (X_test['weekday_trip'] == 'Sunday')) &\
        X_test['hour_trip'].between(5, 6, inclusive=True)
mask = mask1 | mask2
X_test.loc[mask, 'free'] = 1
X_test.loc[~mask, 'free'] = 0
X_test['free'] = X_test['free'].astype(int)

# %% [markdown]
# **Задание 8 (0.25 балла)**.
#
# **(0.05 балла)** Как уже было замечено выше, на карте выделяются две точки вдали от Манхэттена. Для каждой из них добавьте в выборку два признака: началась ли поездка в ней и закончилась ли она в ней.

# %%
lon2, lon1, lat1, lat2 = -73.765333, -73.828333, 40.623333, 40.675333
mask1 = X_train['dropoff_longitude'].between(lon1, lon2, inclusive=True) &\
        X_train['dropoff_latitude'].between(lat1, lat2, inclusive=True)

lon2, lon1, lat1, lat2 = -73.854611, -73.898333, 40.75925, 40.79025
mask2 = X_train['dropoff_longitude'].between(lon1, lon2, inclusive=True) &\
        X_train['dropoff_latitude'].between(lat1, lat2, inclusive=True)

X_train.loc[mask1, 'dropoff_specific_1'] = 1
X_train.loc[~mask1, 'dropoff_specific_1'] = 0
X_train['dropoff_specific_1'] = X_train['dropoff_specific_1'].astype(int)

X_train.loc[mask2, 'dropoff_specific_2'] = 1
X_train.loc[~mask2, 'dropoff_specific_2'] = 0
X_train['dropoff_specific_2'] = X_train['dropoff_specific_2'].astype(int)

# %%
lon2, lon1, lat1, lat2 = -73.765333, -73.828333, 40.623333, 40.675333
mask1 = X_train['pickup_longitude'].between(lon1, lon2, inclusive=True) &\
        X_train['pickup_latitude'].between(lat1, lat2, inclusive=True)

lon2, lon1, lat1, lat2 = -73.854611, -73.898333, 40.75925, 40.79025
mask2 = X_train['pickup_longitude'].between(lon1, lon2, inclusive=True) &\
        X_train['pickup_latitude'].between(lat1, lat2, inclusive=True)

X_train.loc[mask1, 'pickup_specific_1'] = 1
X_train.loc[~mask1, 'pickup_specific_1'] = 0
X_train['pickup_specific_1'] = X_train['pickup_specific_1'].astype(int)

X_train.loc[mask2, 'pickup_specific_2'] = 1
X_train.loc[~mask2, 'pickup_specific_2'] = 0
X_train['pickup_specific_2'] = X_train['pickup_specific_2'].astype(int)

# %%
lon2, lon1, lat1, lat2 = -73.765333, -73.828333, 40.623333, 40.675333
mask1 = X_test['dropoff_longitude'].between(lon1, lon2, inclusive=True) &\
        X_test['dropoff_latitude'].between(lat1, lat2, inclusive=True)

lon2, lon1, lat1, lat2 = -73.854611, -73.898333, 40.75925, 40.79025
mask2 = X_test['dropoff_longitude'].between(lon1, lon2, inclusive=True) &\
        X_test['dropoff_latitude'].between(lat1, lat2, inclusive=True)

X_test.loc[mask1, 'dropoff_specific_1'] = 1
X_test.loc[~mask1, 'dropoff_specific_1'] = 0
X_test['dropoff_specific_1'] = X_test['dropoff_specific_1'].astype(int)

X_test.loc[mask2, 'dropoff_specific_2'] = 1
X_test.loc[~mask2, 'dropoff_specific_2'] = 0
X_test['dropoff_specific_2'] = X_test['dropoff_specific_2'].astype(int)

# %%
lon2, lon1, lat1, lat2 = -73.765333, -73.828333, 40.623333, 40.675333
mask1 = X_test['pickup_longitude'].between(lon1, lon2, inclusive=True) &\
        X_test['pickup_latitude'].between(lat1, lat2, inclusive=True)

lon2, lon1, lat1, lat2 = -73.854611, -73.898333, 40.75925, 40.79025
mask2 = X_test['pickup_longitude'].between(lon1, lon2, inclusive=True) &\
        X_test['pickup_latitude'].between(lat1, lat2, inclusive=True)

X_test = X_test[:]
X_test.loc[mask1, 'pickup_specific_1'] = 1
X_test.loc[~mask1, 'pickup_specific_1'] = 0
X_test['pickup_specific_1'] = X_test['pickup_specific_1'].astype(int)

X_test.loc[mask1, 'pickup_specific_2'] = 1
X_test.loc[~mask1, 'pickup_specific_2'] = 0
X_test['pickup_specific_2'] = X_test['pickup_specific_2'].astype(int)
# Out:
# C:\Users\vk-ks\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\vk-ks\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# <ipython-input-41-1a480b9f1761>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# **(0.1 балл)** Для каждого из созданных признаков нарисуйте "ящик с усами" (`sns.boxplot`) распределения логарифма времени поездки

# %%
plt.figure(figsize=(20,8))

plt.suptitle('Распределение логарифма времени поездки в зависимости от начала поездки', fontsize=15)

plt.subplot(1, 2, 1)
sns.boxplot(x='pickup_specific_1', y=y, data=X_train)
plt.xlabel('pickup_specific_1', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.subplot(1, 2, 2)
sns.boxplot(x='pickup_specific_2', y=y, data=X_train)
plt.xlabel('pickup_specific_2', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(20,8))

plt.suptitle('Распределение логарифма времени поездки в зависимости от конца поездки', fontsize=15)

plt.subplot(1, 2, 1)
sns.boxplot(x='dropoff_specific_1', y=y, data=X_train)
plt.xlabel('dropoff_specific_1', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.subplot(1, 2, 2)
sns.boxplot(x='dropoff_specific_2', y=y, data=X_train)
plt.xlabel('dropoff_specific_2', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(20,8))

plt.suptitle('Распределение логарифма времени поездки в зависимости наличия пробок', fontsize=15)

plt.subplot(1, 2, 1)
sns.boxplot(x='traffic', y=y, data=X_train)
plt.xlabel('Время пробок', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.subplot(1, 2, 2)
sns.boxplot(x='free', y=y, data=X_train)
plt.xlabel('Время свободных дорог', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.show()

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)** судя по графикам, как вы думаете, хорошими ли получились эти признаки?

# %% [markdown]
# **Ответ**: Кажется, что признаки получились не очень хорошими, т.к. на всех графиках наблюдается огромное число выбросов.

# %% [markdown]
# <img src="https://www.dropbox.com/s/xson9nukz5hba7c/map.png?raw=1" align="right" width="20%" style="margin-left: 20px; margin-bottom: 20px">
#
# **Задание 9 (1 балл)**. Сейчас мы почти что не используем сами значения координат. На это есть несколько причин: по отдельности рассматривать широту и долготу не имеет особого смысла, стоит рассматривать их вместе. Во-вторых, понятно, что зависимость между нашим таргетом и координатами не линейная. Чтобы как-то использовать координаты, можно прибегнуть к следующему трюку: обрамим область с наибольшим количеством поездок прямоугольником (как на рисунке). Разобьем этот прямоугольник на ячейки. Каждой точке сопоставим номер ее ячейки, а тем точкам, что не попали ни в одну из ячеек, сопоставим значение -1.
#
# Напишите трансформер, который сначала разбивает показанную на рисунке область на ячейки, а затем создает два признака: номер ячейки, в которой началась поездка, и номер ячейки, в которой закончилась поездка. Количество строк и столбцов выберите самостоятельно.
#
# Обратите внимание, что все вычисления должны быть векторизованными, трансформер не должен модифицировать передаваемую ему выборку inplace, а все необходимые статистики (если они вдруг нужны) нужно считать только по обучающей выборке в методе `fit`:

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class MapGridTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, lat1, lat2, lon1, lon2, n_row, n_clm):
        self.lat_min = lat1
        self.lat_max = lat2
        self.lon_min = lon1
        self.lon_max = lon2
        self.n_row = n_row
        self.n_clm = n_clm
    
    def fit(self, X):
        self.lat_dif = self.lat_max - self.lat_min
        self.lon_dif = self.lon_max - self.lon_min
        self.start_lat_dif = X['pickup_latitude'] - self.lat_min
        self.finish_lat_dif = X['dropoff_latitude'] - self.lat_min
        self.start_lon_dif = X['pickup_longitude'] - self.lon_min
        self.finish_lon_dif = X['dropoff_longitude'] - self.lon_min
    
    def transform(self):
        import copy
        mask_lat = (self.start_lat_dif > 0) & (self.start_lat_dif < self.lat_dif)
        mask_lon = (self.start_lon_dif > 0) & (self.start_lon_dif < self.lon_dif)
        mask = mask_lat & mask_lon
        id_start = copy.deepcopy(mask)
        id_start[~mask] = -1
        j = self.start_lat_dif // (self.lat_dif / self.n_clm)
        i = self.start_lon_dif // (self.lon_dif / self.n_row)
        id_start[mask] = i[mask]*self.n_clm + j[mask]
        
        mask_lat = (self.finish_lat_dif > 0) & (self.finish_lat_dif < self.lat_dif)
        mask_lon = (self.finish_lon_dif > 0) & (self.finish_lon_dif < self.lon_dif)
        mask = mask_lat & mask_lon
        id_finish = copy.deepcopy(mask)
        id_finish[~mask] = -1
        j = self.finish_lat_dif // (self.lat_dif / self.n_clm)
        i = self.finish_lon_dif // (self.lon_dif / self.n_row)
        id_finish[mask] = i[mask]*self.n_clm + j[mask]
        
        return(id_start, id_finish)

# %%
tr = MapGridTransformer(40.709268, 40.800268, -74.024715, -73.929715, 3, 4)
tr.fit(X_train)
id_start, id_finish = tr.transform()
X_train = X_train[:]
X_train['id_start'] = id_start
X_train['id_finish'] = id_finish
X_train['id_start'] = X_train['id_start'].astype(int)
X_train['id_finish'] = X_train['id_finish'].astype(int)

# %%
tr.fit(X_test)
id_start, id_finish = tr.transform()
X_test = X_test[:]
X_test['id_start'] = id_start
X_test['id_finish'] = id_finish
X_test['id_start'] = X_test['id_start'].astype(int)
X_test['id_finish'] = X_test['id_finish'].astype(int)

# %% [markdown]
# **Задание 10 (0.25 балла)**. Обучите `Ridge`-регрессию со стандартными параметрами на признаках, которые мы выделили к текущему моменту, закодировав категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`.

# %%
numeric_features += ['log_haversine']
categorical = categorical + ['pickup_specific_1', 'pickup_specific_2', 'traffic', 'free', 'dropoff_specific_1', 
                                      'dropoff_specific_2', 'id_start', 'id_finish']

# %%
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

ridge_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

# %%
model = ridge_pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSLE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSLE = 0.2320

# %% [markdown]
# ## Часть 3. Изучаем оставшиеся признаки (1 балл)
#
# **Задание 11 (0.75 баллов)**.
#
# У нас осталось еще 3 признака, которые мы не исследовали: `vendor_id`, `passenger_count` и `store_and_fwd_flag`.
#
# **Вопрос (0.1 балл)**: **(?)** Подумайте, почему каждый из этих признаков может быть потенциально полезным.
#
# **Ответ**: passenger_count может быть полезен тем, что когда едет немного человек(1-2), они возможно едут по делам, по работе, поэтому они скорее всего передвигаются на небольшое расстояние в пределах Манхэттена. Если же едет много человек, то вероятно они едут в гости, отдыхать, в аэропорт и т.п. Поэтому есть вероятность, что они проедут большое расстояние, что влечёт за собой длительную поездку.\
# store_and_fwd_flag показывает хранилась ли в памяти таксометра какое-то время информация о поездке. Если да, то также могли быть ещё какие-либо проблемы(связанные с неисправностью таксометра или за это время могло быть потеряно часть информации). Поэтому такие данные могут быть неинформативными.

# %% [markdown]
# **(0.1 балл)** Посчитайте, сколько есть уникальных значений у каждого из этих признаков:

# %%
print(f'unique vendor_id = {X.vendor_id.nunique(dropna = True)}')
print(f'unique passenger_count = {X.passenger_count.nunique(dropna = True)}')
print(f'unique store_and_fwd_flag = {X.store_and_fwd_flag.nunique(dropna = True)}')
# Out:
# unique vendor_id = 2
# unique passenger_count = 10
# unique store_and_fwd_flag = 2

# %% [markdown]
# **(0.2 балла)** Постройте "ящики с усами" распределений логарифма времени поездки в зависимости от значений каждого из признаков

# %%
plt.figure(figsize=(20,8))

plt.suptitle('Распределение логарифма времени поездки в зависимости от значений признаков', fontsize=15)

plt.subplot(1, 2, 1)
sns.boxplot(x='vendor_id', y=y, data=X)
plt.xlabel('vendor_id', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.subplot(1, 2, 2)
sns.boxplot(x='passenger_count', y=y, data=X)
plt.xlabel('passenger_count', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.suptitle('Распределение логарифма времени поездки в зависимости от значений признаков', fontsize=15)
sns.boxplot(x='store_and_fwd_flag', y=y, data=X)
plt.xlabel('store_and_fwd_flag', fontsize=15)
plt.ylabel('log_trip_duration', fontsize=15)

plt.show()

# %% [markdown]
# **(0.2 балла)** Переведите признаки `vendor_id` и `store_and_fwd_flag` в значения $\{0;1\}$

# %%
X_train = X_train[:]
X_train['vendor_id'] = X_train['vendor_id'] - 1
X_train.loc[(X.store_and_fwd_flag == 'N'), 'store_and_fwd_flag'] = 0
X_train.loc[(X.store_and_fwd_flag == 'Y'), 'store_and_fwd_flag'] = 1

X_test = X_test[:]
X_test['vendor_id'] = X_test['vendor_id'] - 1
X_test.loc[(X.store_and_fwd_flag == 'N'), 'store_and_fwd_flag'] = 0
X_test.loc[(X.store_and_fwd_flag == 'Y'), 'store_and_fwd_flag'] = 1

# %% [markdown]
# **Вопрос (0.15 балла)**: **(?)** Основываясь на графиках выше, как вы думаете, будут ли эти признаки сильными?

# %% [markdown]
# **Ответ**: Кажется, что признаки получились не очень хорошими, т.к. на всех графиках наблюдается огромное число выбросов. И практически все боксы находятся на одной прямой и имееют одинаковую форму.

# %% [markdown]
# **Задание 12 (0.25 баллов)**. Проверьте свои предположения, обучив модель **в том числе и на этих трех признаках.** Обучайте `Ridge`-регрессию со стандартными параметрами, закодировав  категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`.

# %%
categorical += ['passenger_count', 'store_and_fwd_flag', 'vendor_id']

# %%
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

ridge_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

# %%
model = ridge_pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSE = 0.2317

# %% [markdown]
# Если признаки не дали какого-то ощутимого улучшения метрики, их можно выбросить из данных.

# %% [markdown]
# ## Часть 4. Улучшаем модель (3 балла)

# %% [markdown]
# **Задание 13 (1 балл)**.
#
# В наших данных есть нетипичные объекты: с аномально маленьким времени поездки, с очень большим пройденным расстоянием или очень большими остатками регрессии. В этом задании предлагается исключить такие объекты из обучающей выборки.
#
#
# **(0.3 балла)** Для этого нарисуйте гистограммы распределения упомянутых выше величин, выберите объекты, которые можно назвать выбросами, и очистите обучающую выборку от них.
#
# Отметим, что хотя эти объекты и выглядят как выбросы, в тестовой выборке тоже скорее всего будут объекты с такими же странными значениями целевой переменной и/или признаков. Поэтому, возможно, чистка обучающей выборки приведёт к ухудшению качества на тесте. Тем не менее, всё равно лучше удалять выбросы из обучения, чтобы модель получалась более разумной и интерпретируемой.

# %%
error = (y_train - model.predict(X_train)) ** 2

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.title('Гистограмма распределения log_trip_duration', fontsize=10)
plt.hist(y_train, bins=100)
plt.xlabel('log(trip_duration)', fontsize=15)
plt.ylabel('number of train records', fontsize=15)
plt.grid(True)

plt.subplot(1, 2, 2)
plt.title('Гистограмма распределения пройденного расстояния', fontsize=10)
plt.hist(X_train['haversine'], bins=100)
plt.xlabel('haversine', fontsize=15)
plt.ylabel('number of train records', fontsize=15)
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.title('Гистограмма распределения остатков регрессии', fontsize=15)
plt.hist(error, bins=100)
plt.xlabel('остатки регрессии', fontsize=15)
plt.ylabel('number of train records', fontsize=15)
plt.grid(True)
plt.show()

# %%
mask1 = (error < np.quantile(error, 0.999))
mask2 = (X_train['haversine'] < np.quantile(X_train['haversine'], 0.99999))
mask3 = (y_train > np.quantile(y_train, 0.002))
mask = mask1 & mask2 & mask3

# %%
X_train = X_train[mask]
y_train = y_train[mask]

# %% [markdown]
# **(0.3 балла)** Сейчас у нас очень много категориальных признаков. В категориальных признаках могут содержаться редкие категории, обычно это плохо: модель сильно переобучается на таких примерах. Попробуйте объединить редкие категории в одну. Естественно, делать это нужно только для действительно редких категорий.

# %%
X_train['weekday_trip'].value_counts()
# Out:
# Friday       156332
# Saturday     154338
# Thursday     152302
# Wednesday    146628
# Tuesday      141343
# Sunday       136053
# Monday       130944
# Name: weekday_trip, dtype: int64

# %%
X_train['month_trip'].value_counts()
# Out:
# March       179054
# April       175275
# May         173095
# February    166581
# June        163476
# January     160459
# Name: month_trip, dtype: int64

# %%
X_train['abnormal_day_2'].value_counts(), X_train['abnormal_day_1'].value_counts()
# Out:
# (0    1004702
#  1      13238
#  Name: abnormal_day_2, dtype: int64,
#  0    1008312
#  1       9628
#  Name: abnormal_day_1, dtype: int64)

# %%
X_train['pickup_specific_1'].value_counts(), X_train['pickup_specific_2'].value_counts()
# Out:
# (0    995663
#  1     22277
#  Name: pickup_specific_1, dtype: int64,
#  0    991965
#  1     25975
#  Name: pickup_specific_2, dtype: int64)

# %%
X_train['dropoff_specific_1'].value_counts(), X_train['dropoff_specific_2'].value_counts()
# Out:
# (0    1008718
#  1       9222
#  Name: dropoff_specific_1, dtype: int64,
#  0    1004813
#  1      13127
#  Name: dropoff_specific_2, dtype: int64)

# %%
X['passenger_count'].value_counts()
# Out:
# 1    1033540
# 2     210318
# 5      78088
# 3      59896
# 6      48333
# 4      28404
# 0         60
# 7          3
# 9          1
# 8          1
# Name: passenger_count, dtype: int64

# %%
X_train['traffic'].value_counts(), X_train['free'].value_counts()
# Out:
# (0    543750
#  1    474190
#  Name: traffic, dtype: int64,
#  0    999136
#  1     18804
#  Name: free, dtype: int64)

# %%
X_train['store_and_fwd_flag'].value_counts(), X_train['vendor_id'].value_counts()
# Out:
# (0    1012333
#  1       5607
#  Name: store_and_fwd_flag, dtype: int64,
#  1    543945
#  0    473995
#  Name: vendor_id, dtype: int64)

# %%
X_train['id_start'].value_counts(), X_train['id_finish'].value_counts()
# Out:
# ( 6     255776
#   5     202412
#   1     107094
#  -1     105442
#   0      86437
#   10     64972
#   7      64022
#   4      57689
#   11     49466
#   2      17816
#   8       3957
#   9       2848
#   3          9
#  Name: id_start, dtype: int64,
#   6     230249
#   5     189704
#  -1     155079
#   1      88855
#   0      78440
#   10     66487
#   7      62370
#   11     56721
#   4      53808
#   2      22048
#   8       8583
#   9       5554
#   3         42
#  Name: id_finish, dtype: int64)

# %% [markdown]
# В passenger_count можно объединить 0, 7, 8, 9. А объединение ячеек id_start и id_finish не даёт никакого преимущества, поэтому не будем это делать.

# %%
mask = ((X_train['passenger_count'] < 10) & (X_train['passenger_count'] > 6)) | (X_train['passenger_count'] == 0)
X_train.loc[mask, 'passenger_count'] = 0
mask = ((X_test['passenger_count'] < 10) & (X_test['passenger_count'] > 6)) | (X_test['passenger_count'] == 0)
X_test.loc[mask, 'passenger_count'] = 0

# %% [markdown]
# **(0.4 балла)**Обучите модель на очищенных данных и посчитайте качество на тестовой выборке.

# %%
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

ridge_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = ridge_pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RLMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RLMSE = 0.2316

# %% [markdown]
# **Задание 14 (1 балл)**.
#
# **(0.1 балл)** После OneHot-кодирования количество признаков в нашем датасете сильно возрастает. Посчитайте колиество признаков до и после кодирования категориальных признаков.

# %%
print("Size before OneHot:", len(categorical) + len(numeric_features))
print("Size after OneHot:", column_transformer.transform(X_train).shape[1])
# Out:
# Size before OneHot: 18
# Size after OneHot: 69

# %% [markdown]
# **(0.2 балла)** Попробуйте обучить не `Ridge`-, а `Lasso`-регрессию. **(?)** Какой метод лучше?

# %%
from sklearn.linear_model import Lasso

# %%
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

lasso_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso())
])

model = lasso_pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("RLMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# RLMSE = 0.6309

# %% [markdown]
# **Ответ**: Видно, что Ridge работает намного лучше, чем Lasso. А работа Lasso по точности примерна равна константному приближению

# %% [markdown]
# **(0.5 балла)** Разбейте обучающую выборку на обучающую и валидационную в отношении 8:2. По валидационной выборке подберите оптимальные значения параметра регуляризации (по логарифмической сетке) отдельно для `Ridge` и отдельно для `Lasso`, на тестовой выборке измерьте качество лучшей полученной модели.

# %%
from sklearn.model_selection import GridSearchCV

X_train_tr, X_val, y_train_tr, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=10)

# %%
alphas = np.logspace(-2, 3, 20)
res_lasso, res_ridge = np.array([]), np.array([])
for alpha in alphas:
    lasso_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso(alpha=alpha))
    ])
    lasso_model = lasso_pipeline.fit(X_train_tr, y_train_tr)
    y_pred = lasso_model.predict(X_val)
    res_lasso = np.append(res_lasso, mean_squared_error(y_val, y_pred, squared=True))
    
    
    ridge_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge(alpha=alpha))
    ])
    ridge_model = ridge_pipeline.fit(X_train_tr, y_train_tr)
    y_pred = ridge_model.predict(X_val)
    res_ridge = np.append(res_ridge, mean_squared_error(y_val, y_pred, squared=True))

# %%
plt.figure(figsize=(15,7))

plt.subplot(1, 2, 1)
plt.title('Зависимость качества Ridge от параметра регуляризации', fontsize=13)
plt.plot(alphas, res_ridge, color='r', label='Ridge')
plt.grid(True) 
plt.xscale("log")
plt.xlabel("alpha")
plt.ylabel("RMSLE")
plt.yscale("logit")

plt.subplot(1, 2, 2)
plt.title('Зависимость качества Lasso от параметра регуляризации', fontsize=13)
plt.plot(alphas, res_lasso, label='Lasso')
plt.grid(True) 
plt.xscale("log")
plt.xlabel("alpha")
plt.ylabel("RMSLE")

plt.show()

# %% [markdown]
# Видим, что при малых значениях альфы Ridge и Lasso выдают практически одинаковую точность. Происследуем, как видёт себя ошибка при ещё меньших альфа

# %%
alphas = np.logspace(-4, -2, 15)
res_lasso, res_ridge = np.array([]), np.array([])
for alpha in alphas:
    lasso_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso(alpha=alpha))
    ])
    lasso_model = lasso_pipeline.fit(X_train_tr, y_train_tr)
    y_pred = lasso_model.predict(X_val)
    res_lasso = np.append(res_lasso, mean_squared_error(y_val, y_pred, squared=True))
    
    
    ridge_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge(alpha=alpha))
    ])
    ridge_model = ridge_pipeline.fit(X_train_tr, y_train_tr)
    y_pred = ridge_model.predict(X_val)
    res_ridge = np.append(res_ridge, mean_squared_error(y_val, y_pred, squared=True))

# %%
plt.figure(figsize=(15,7))

plt.title('Зависимость качества модели от параметра регуляризации', fontsize=13)
plt.plot(alphas, res_ridge, color='r', label='Ridge')
plt.plot(alphas, res_lasso, label='Lasso')
plt.grid(True) 
plt.xscale("log")
plt.xlabel("alpha")
plt.ylabel("RMSLE")

plt.legend(fontsize=10)

# %%
plt.figure(figsize=(15,7))

plt.subplot(1, 2, 1)
plt.title('Зависимость качества Ridge от параметра регуляризации', fontsize=13)
plt.plot(alphas, res_ridge, color='r', label='Ridge')
plt.grid(True) 
plt.xscale("log")
plt.xlabel("alpha")
plt.ylabel("RMSLE")
#plt.ylim([min(res_ridge), max(res_ridge)])
plt.yscale("logit")

plt.subplot(1, 2, 2)
plt.title('Зависимость качества Lasso от параметра регуляризации', fontsize=13)
plt.plot(alphas, res_lasso, label='Lasso')
plt.grid(True) 
plt.xscale("log")
plt.xlabel("alpha")
plt.ylabel("RMSLE")



plt.show()

# %% [markdown]
# Видим, что при малых значениях альфы ошибка на Lasso и на Ridge практически одинаковая. Но при таких значениях Lasso работает существенно медленнее, поэтому выберем наилучшее значение альфы для Ridge и дальше будем использовать его.

# %%
best_alpha = alphas[np.argmin(res_ridge)]

# %% [markdown]
# **(0.2 балла)** Для каждого перебранного `alpha` для Lasso посчитайте количество нулевых весов в модели и нарисуйте график зависимости его от `alpha`. **(?)** Как сильно придётся потерять в качестве, если мы хотим с помощью Lasso избавиться хотя бы от половины признаков?

# %%
alphas = np.logspace(-4, 3, 35)
lasso_zeros = np.array([])
for alpha in alphas:
    lasso_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso(alpha=alpha))
    ])
    lasso_model = lasso_pipeline.fit(X_train_tr, y_train_tr)
    y_pred = lasso_model.predict(X_val)
    lasso_zeros = np.append(lasso_zeros,np.sum(lasso_pipeline.steps[-1][-1].coef_ == 0))

# %%
plt.figure(figsize=(15,7))
plt.title('Зависимость количества нулевых признаков от параметра регуляризации', fontsize=13)
plt.plot(alphas, lasso_zeros)
plt.grid(True) 
plt.xscale("log")
plt.xlabel("alpha")
plt.ylabel("Количество нулевых признаков")
# Out:
# Text(0, 0.5, 'Количество нулевых признаков')

# %% [markdown]
# Из графика видно, что чем больше альфа, тем больше признаков зануляет Lasso. Из предыдущих графиков, можно заметить, что соответственно увеличивается и ошибка. Если мы хотим избавиться примерно от половины признаков, то данному случаю соответствует альфа примерно $10^{-3}$. При таком альфа ошибка на Lasso не сильно отличается от Ridge, следовательно потеряем мы немного.

# %% [markdown]
# <img src="https://www.dropbox.com/s/wp4jj0599np17lh/map_direction.png?raw=1" width="20%" align="right" style="margin-left: 20px">
#
# **Задание 15 (1 балл + 1 бонус)**.
#
# **(0.7 баллов)** Часто бывает полезным использовать взаимодействия признаков (feature interactions), то есть строить новые признаки на основе уже существующих. Выше мы разбили карту Манхэттена на ячейки и придумали признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка".
#
# Давайте попробуем сделать следующее: посчитаем, сколько раз встречается каждая возможная пара этих признаков в нашем датасете и выберем 100 самых частых пар. Закодируем поездки с этими частыми парами как категориальный признак, остальным объектам припишем -1. Получается, что мы закодировали, откуда и куда должно было ехать такси.
#
# Также можете придумать ещё какой-нибудь способ сделать признаки про маршрут. Если эти признаки будут давать хороший прирост в качестве, то за это могут быть даны дополнительные бонусные баллы **(до 1 бонусного балла)**

# %%
def num_pair(elem):
    if elem in pairs:
        pair = pairs.index(elem)
    else:
        pair = -1
    if pair >= 100:
        pair = -1
    return pair

X_train['pairs'] = list(zip(X_train['id_start'], X_train['id_finish']))
pairs = list(X_train['pairs'].value_counts().index)
X_train['pairs'] = X_train['pairs'].apply(num_pair)

X_test['pairs'] = list(zip(X_test['id_start'], X_test['id_finish']))
X_test['pairs'] = X_test['pairs'].apply(num_pair)

# %% [markdown]
# **Вопрос (0.2 балла)**: **(?)** Почему такой признак потенциально полезный? Почему линейная модель не может самостоятельно "вытащить" эту информацию, ведь у нее в распоряжении есть признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка"?

# %% [markdown]
# **Ответ**: Такой признак может быть полезен, т.к. мы можем найти наиболее популярные маршруты поездок. И посмотреть, как от этого зависит таргет. Время всё же зависит не только от расстояния, а ещё, к примеру, от траектории движения. Т.к. на разных улицах могут быть свои особенности(много светофоров, ограничения на скорость и прочее). А в тестовой выборке скорее всего большее количество элементов именно из этих 100 групп, поэтому, предсказывая время таких поездок, мы должны обращать внимание на соответствующие группы из обучающейся выборки. Линенйная модель не может сама "вытащить" эту информацию, т.к. собственно группировка и взятие максимума не линейная функция. Поэтому приходится самостоятельно добавлять эту зависимость.

# %% [markdown]
# **(0.1 балл)** Заново обучите модель (`Ridge`, если она дала более высокое качество в предыдущих экспериментах, и `Lasso` иначе) на новых даннных и посчитайте качество на тестовой выборке

# %%
categorical += ['pairs']

# %%
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

ridge_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge(alpha=best_alpha))
])

model = ridge_pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSLE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSLE = 0.2232

# %% [markdown]
# **Задание 16 (бонус, 1 балл)**. Где, как не для нашей задачи, считать манхэттенское расстояние?
#
# **Вопрос (0.2 балла)**: **(?)** Найдите, что такое манхэттенское расстояние и почему оно так называется. Как оно нам может помочь?
#
# **Ответ**: Манхэттенским называется расстояние городских кварталов между двумя векторами ${x}$ и ${y}$ в n-мерном вещественном векторном пространстве с заданной системой координат, равное сумме длин проекций отрезка между точками на оси координат. Т.е.
# $\rho(x, y) = \sum _{i=1}^{n}|x_{i}-y_{i}|$\
# Оно так называется, т.к. в Манхэттене все улицы идут параллельно или перпендикулярно друг другу. И чтобы найти расстояние, которое мы преодолеем, двигаясь по дороге, от одной точки до другой, надо воспользоваться именно этой формулой. Т.к. евклидово расстояние считает путь напрямую. Очевидно, мы не сможем так ехать. Нам необходимо будет передвигаться только по дороге. Именно это и учитывает эта формула. Поэтому она может внести существенный вклад в нашу модель.

# %% [markdown]
# **(0.5 балла)** Введите систему координат на нашей карте так, чтобы оси были параллельны улицам Манхэттена, и добавьте сначала в данные признак "манхэттенское расстояние между пунктом отправления и пунктом назначения", а затем и логарифм этого признака. Посчитайте корреляцию между вашим новыми признаком и таргетом; между `log_haversine` и таргетом. В каком случае корреляция больше?
#
# Нарисуйте карту, где покажете выбранные оси. Чтобы мы могли проверить вашу работу, просьба сделать скрин этой карты и приложить картинку (если мы откроем ваш ноутбук, виджеты отображаться не будут).

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **(0.3 балла)** Заново обучите модель на новых даннных и посчитайте качество на тестовой выборке. **(?)** Стало ли лучше? Объясните полученный результат.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Задание 17 (бонус, 2 балла)**. Реализуйте трансформер, который строит разбиение карты по шестигранной решётке с помощью библиотеки [H3](https://github.com/uber/h3-py) и вычисляет признаки на основе такого разбиения.
#
# Признаки могут быть самые разные: расстояние между точкой старта и финиша, посчитанное в количестве шестиугольников; статистика по числу поездок и по их продолжительности в соседних шестиугольниках.
#
# Важно: производительность библиотеки существенно зависит от количества шестиугольников на карте (определяется параметром resolution). Подберите такое разрешение, при котором ваш код будет работать за приемлемое время.
#
# При построении признаков старайтесь не допустить утечки целевой переменной --- в противном случае хорошего качества на тестовой выборке достичь не получится.
#
# Измерьте качество после добавления новых признаков. За улучшение функционала ошибки на каждые 0.005 на тестовой выборке будет даваться 0.5 бонусных балла. Можно получить до 2 бонусных баллов за это задание.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Бонус (0.3 балла)** Вставьте картинку, описывающую ваш опыт выполнения этого ДЗ.

# %% [markdown]
# <img src="https://cproc.ru/upload/iblock/fec/fecc7215e8566cd54673f066712ea5c7.jpg" style="width: 400px">
