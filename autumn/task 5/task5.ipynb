# %% [markdown]
# # Машинное обучение, ВМК МГУ
#
# ## Практическое задание 4. Разложение ошибки на смещение и разброс. Градиентный бустинг ~~своими руками~~
#
# ### Общая информация
#
# Дата выдачи: 25.11.2021
#
# Мягкий дедлайн: 23:59MSK 09.12.2021
#
# Жесткий дедлайн: 23:59MSK 16.12.2021
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — **10 баллов + 0.5 бонусов**. Проверяющий имеет право снизить оценку за неэффективную реализацию или неопрятные графики.
#
# **Обратите внимание**, что в каждом разделе домашнего задания есть оцениваниемые задачи и есть вопросы. Вопросы дополняют задачи и направлены на то, чтобы проинтерпретировать или обосновать происходящее. Код без интерпретации не имеет смысла, поэтому отвечать на вопросы обязательно — за отсутствие ответов мы будем снижать баллы за задачи. Если вы ответите на вопросы, но не напишете корректный код к соответствующим оцениваемым задачам, то баллы за такое выставлены не будут.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# <p style="color:#de3815;font-size:25px;">
# Напоминание об оформлении и выполнении ноутбука
# </p>
#
# * Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть, не запуская ячейки (кроме редких случаев, когда необходимо намеренно скрыть ненужный output, про такие случаи желательно писать пояснения в тексте). **В противном случае -1 балл**
# * При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. **Не нужно** удалять и видоизменять написанный код и текст, если явно не указана такая возможность. Создавать новые ячейки с кодом/текстов там, где это осмысленно и вы считаете необходимым, конечно, можно. **В противном случае -1 балл**
# * В anytask обязательно нужно прикреплять отдельно файл с расширением ipynb (не в архиве, а именно отдельно). Если необходимо отправить еще какие-то файлы, то вынесите их в отдельный архив (если файлов много) и пришлите. **В противном случае -0.5 балла**
# ---
# * Пишите, пожалуйста, выводы и ответы на вопросы в текстовых ячейках/при помощи print в коде/как результат вывода ячейки. При их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и **поэтому будем снижать баллы**
# * Если алгоритм не сказано реализовывать явно, его всегда можно импортировать из библиотеки.
# ---
# * Про графики. _Штрафы будут применяться к каждому результату команды отображения графика (plt.show() и др. аналогичные). Исключением являются графики, генерируемые функциями каких-либо сторонних библиотек, если их нельзя кастомизировать_
#
#     * должно быть название (plt.title) графика; **В противном случае &ndash; -0.05 балла**
#     * на графиках должны быть подписаны оси (plt.xlabel, plt.ylabel); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * должны быть подписаны единицы измерения (если это возможно); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * все названия должны быть понятны любому человеку, знакомому с терминологией, без заглядывания в код; **В противном случае &ndash; -0.05 балла**
#     * подписи тиков на осях не должны сливаться как на одной оси, так и между ними; **В противном случае &ndash; -0.025 балла за каждую ось**
#     * если изображено несколько сущностей на одном холсте (например несколько функций), то необходима поясняющая легенда (plt.legend); **В противном случае &ndash; -0.05 балла**
#     * все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном); **В противном случае &ndash; -0.05 балла**
#     * если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
#     * графики должны быть не супер-микро и не супер-макро по размерам, так, чтобы можно было увидеть все, что нужно.
#     * при необходимости улучшения наглядности графиков, можно пользоваться логарифмической шкалой по осям x/y.
#
# ### А также..
#
# * Для удобства поиска вопросов, на которые от вас просят ответа, мы пометили их знаком **(?)**
# * Знак **(!)** означает, что выполнение замечания необходимо для **возможности получения полного балла**
# * Даем до +0.3 баллов за выдающиеся успехи по субъективному мнению проверяющих. Этот **бонус** не апеллируется
#
# ### О задании
#
# В этом задании вам предстоит воспользоваться возможностями bootstraping для оценки смещения и разброса алгоритмов машинного обучения. Делать мы это будем на данных boston.
# Также в задании вам будет предложено пообучать готовые модели градиентного бустинга и CatBoost.

# %% [markdown]
# **Напоминание:**
#
# * Все ваши графики должны быть **"красивыми"** --- подробнее о том, как их оформлять, можно найти в первом практическом задании. При несоответствии какиму-то из критериев вам могут снять баллы.
# * Пишите в текстовых ячейках/print в коде ответы на **все вопросы из заданий/просьбы сделать выводы** --- при их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и поэтому будем снижать баллы

# %% [markdown]
# ## Часть 1. Bias-Variance Decomposition

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
X = boston["data"]
y = boston["target"]

# %%
X.shape, y.shape
# Out:
# ((506, 13), (506,))

# %% [markdown]
# ### Вычисление bias и variance с помощью бутстрапа
# На лекции была выведено следующая формула, показывающая, как можно представить ошибку алгоритма регрессии в виде суммы трех компонент:
# $$
# L(\mu) =
#     \mathbb{E}_{x, y}\bigl[\mathbb{E}_{X}\bigl[ (y - \mu(X)(x))^2 \bigr]\bigr] =
# $$
# $$
#     \underbrace{\mathbb{E}_{x, y}\bigl[(y - \mathbb{E}[y|x] )^2\bigr]}_{\text{шум}} + \underbrace{\mathbb{E}_{x}\bigl[(\mathbb{E}_{X}[\mu(X)(x)] - \mathbb{E}[y|x] )^2\bigr]}_{\text{смещение}} +
#     \underbrace{\mathbb{E}_{x}\bigl[\mathbb{E}_{X}\bigl[(\mu(X)(x) - \mathbb{E}_{X}[\mu(X)(x)] )^2\bigr]\bigr]}_{\text{разброс}},
# $$
# * $\mu(X)$ — алгоритм, обученный по выборке $X = \{(x_1, y_1), \dots (x_\ell, y_\ell)\}$;
# * $\mu(X)(x)$ — ответ алгоритма, обученного по выборке $X$, на объекте $x$;
# * $\mathbb{E}_{X}$ — мат. ожидание по всем возможным выборкам;
# * $\mathbb{E}_{X}[\mu(X)(x)]$ — "средний" ответ алгоритма, обученного по всем возможным выборкам $X$, на объекте $x$.
#
# С помощью этой формулы мы можем анализировать свойства алгоритма обучения модели $\mu$, если зададим вероятностную модель порождения пар $p(x, y)$.
#
# В реальных задачах мы, конечно же, не знаем распределение на парах объект - правильный ответ. Однако у нас есть набор семплов из этого распределения (обучающую выборка), и мы можем использовать его, чтобы оценивать математические ожидания. Для оценки мат. ожиданий по выборкам мы будем пользоваться бутстрэпом - методом генерации "новых" выборок из одной с помощью выбора объектов с возвращением. Разберем несколько шагов на пути к оценке смещения и разброса.
#
# #### Приближенное вычисление интегралов
# На занятиях мы разбирали примеры аналитического вычисления смещения и разброса нескольких алгоритмов обучения. Для большинства моделей данных и алгоритмов обучения аналитически рассчитать математические ожидания в формулах не удастся. Однако мат. ожидания можно оценивать приближенно. Чтобы оценить математическое ожидание $\mathbb{E}_{\bar z} f(\bar z)$ функции от многомерной случайной величины $\bar z = (z_1, \dots, z_d)$, $\bar z \sim p(\bar z)$, можно сгенерировать выборку из распределения $p(\bar z)$ и усреднить значение функции на элементах этой выборки:
# $$\mathbb{E}_{\bar z} f(z) = \int f(\bar z) p(\bar z) d \bar z \approx \frac 1 m \sum_{i=1}^m f(\bar z_i), \, \bar z_i \sim p(\bar z), i = 1, \dots, m.$$
#
# Например, оценим $\mathbb{E}_z z^2,$ $z \sim \mathcal{N}(\mu=5, \sigma=3)$ (из теории вероятностей мы знаем, что
# $\mathbb{E}_z z^2 = \sigma^2 + \mu^2 = 34$):

# %%
z = np.random.normal(loc=5, scale=3, size=1000)
(z**2).mean()
# Out:
# 32.55634943056367

# %% [markdown]
# #### Оценивание $\mathbb{E}_{x, y}$
# Оценить мат. ожидания по $x$ и по $x, y$, встречающиеся во всех трех компонентах разложения, несложно, потому что у нас есть выборка объектов из распределения данных $p(x, y)$:
# $$ \mathbb{E}_{x} f(x) \approx \frac 1 N \sum_{i=1}^N f(x_i), \quad
# \mathbb{E}_{x, y} f(x, y) \approx \frac 1 N \sum_{i=1}^N f(x_i, y_i),$$
# где $N$ - число объектов в выборке, $\{(x_i, y_i)\}_{i=1}^N$ - сама выборка.
#
# #### Оценивание $\mathbb{E}_X$ с помощью бутстрапа
# Чтобы оценить мат. ожидание по $X$, нам понадобится выборка из выборок:
# $$\mathbb{E}_X f(X) \approx \frac 1 s \sum_{j=1}^s f(X_j),$$
# где $X_j$ - $j$-я выборка. Чтобы их получить, мы можем воспользоваться бутстрапом - методом генерации выборок на основе выбора объектов с возвращением. Чтобы составить одну выборку, будем $N$ раз выбирать индекс объекта $i \sim \text{Uniform}(1 \dots N)$ и добавлять $i$-ю пару (объект, целевая переменная) в выборку. В результате в каждой выборке могут появиться повторяющиеся объекты, а какие-то объекты могут вовсе не войти в некоторые выборки.
#
# #### Итоговый алгоритм оценки смещения и разброса алгоритма $a$
# 1. Сгенерировать $s$ выборок $X_j$ методом бутстрапа.
# 1. На каждой выборке $X_j$ обучить алгоритм $a_j$.
# 1. Для каждой выборки $X_j$ определить множество объектов $T_j$, не вошедших в нее (out-of-bag). Вычислить предсказания алгоритма $a_j$ на объектах $T_j$.
#
# Поскольку у нас есть только один ответ для каждого объекта, мы будем считать шум равным 0, а $\mathbb{E}[y|x]$ равным имеющемуся правильному ответу для объекта $x$.
#
# Итоговые оценки:
# * Смещение: для одного объекта - квадрат разности среднего предсказания и правильного ответа. Среднее предсказание берется только по тем алгоритмам $a_j$, для которых этот объект входил в out-of-bag выборку $T_j$. Для получения общего смещения выполнить усреденение смещений по объектам.
# * Разброс: для одного объекта - выборочная дисперсия предсказаний алгоритмов $a_j$, для которых этот объект входил в out-of-bag выборку $T_j$. Для получения общего разброса выполнить усреденение разбросов по объектам.
# * Ошибка $L$: усреднить квадраты разностей предсказания и правильного ответа по всем выполненным предсказаниям для всех объектов.
#
# В результате должно получиться, что ошибка приблизительно равна сумме смещения и разброса!
#
# Алгоритм также вкратце описан по [ссылке](https://web.engr.oregonstate.edu/~tgd/classes/534/slides/part9.pdf) (слайды 19-21).
#
# __Задание 1. (1.5 баллa)__
#
# Реализуйте описанный алгоритм. Обратите внимание, что если объект не вошел ни в одну из out-of-bag выборок, учитывать его в вычислении итоговых величин не нужно. Как обычно, разрешается использовать только один цикл - по выборкам (от 0 до num_runs-1).

# %% [markdown]
# Выборочная дисперсия $S_n$ для одного объекта вычисляется по следующей формуле:
# $$S_n = \frac{1}{k}\sum (pred_j - \overline{pred})^2,$$
# где сумма берётся только по тем алгоритмам $a_j$, для которых этот объект входил в out-of-bag выборку $T_j$, $k$ - их количество, а $\overline{pred}$ - их среднее.
# Тогда получим:\
# $S_n = \frac{1}{k}\sum(pred_j^2) - \frac{2}{k}\overline{pred}\sum(pred_j) + \overline{pred}^2 = \frac{1}{k}\sum(pred_j^2) - 2\overline{pred}^2 + \overline{pred}^2 = \frac{1}{k}\sum(pred_j^2) - \overline{pred}^2$

# %%
def compute_biase_variance(regressor, X, y, num_runs=1000):
    """
    :param regressor: sklearn estimator with fit(...) and predict(...) method
    :param X: numpy-array representing training set ob objects, shape [n_obj, n_feat]
    :param y: numpy-array representing target for training objects, shape [n_obj]
    :param num_runs: int, number of samples (s in the description of the algorithm)
    
    :returns: bias (float), variance (float), error (float) 
    each value is computed using bootstrap
    """
    ### your code here ╰( ͡° ͜ʖ ͡° )つ──☆*:
    all_idx = np.arange(X.shape[0])
    bias_out_of_bag = np.zeros(X.shape[0])
    sq_bias_out_of_bag = np.zeros(X.shape[0])
    num_in_oob = np.zeros(X.shape[0])
    error_out_of_bag, num_out_of_bag = 0, 0
    
    for i in range(num_runs):
        boot_idx = np.random.randint(0, X.shape[0], X.shape[0])
        val_idx = np.delete(all_idx, boot_idx)
        
        X_train, y_train = X[boot_idx], y[boot_idx]
        X_val, y_val = X[val_idx], y[val_idx]
        
        regressor.fit(X_train, y_train)
        y_pred = regressor.predict(X_val)
        
        num_in_oob[val_idx] += 1
        bias_out_of_bag[val_idx] += y_pred
        sq_bias_out_of_bag[val_idx] += y_pred**2
        error_out_of_bag += ((y_pred - y_val)**2).sum()
        num_out_of_bag += len(val_idx)
        
    bias = ((bias_out_of_bag[num_in_oob > 0] / num_in_oob[num_in_oob > 0] - y[num_in_oob > 0])**2).mean()
    variance = ( sq_bias_out_of_bag[num_in_oob > 0] / num_in_oob[num_in_oob > 0] -\
                (bias_out_of_bag[num_in_oob > 0] / num_in_oob[num_in_oob > 0])**2).mean()
    error = error_out_of_bag / num_out_of_bag
    
    return bias, variance, error

# %% [markdown]
# **Задание 2. (0.5 баллa)**
#
# **(0.3 балла)** Оцените смещение, разброс и ошибку для трех алгоритмов с гиперпараметрами по умолчанию: линейная регрессия, решающее дерево, случайный лес.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
compute_biase_variance(LinearRegression(), X, y, num_runs=1000)
# Out:
# (23.74994935648457, 0.935274646448773, 24.586193533224392)

# %%
compute_biase_variance(DecisionTreeRegressor(), X, y, num_runs=1000)
# Out:
# (10.172588671615827, 13.123581898148819, 23.249759879886334)

# %%
compute_biase_variance(RandomForestRegressor(), X, y, num_runs=1000)
# Out:
# (10.701714154568299, 2.2538124071516417, 13.029210272971403)

# %% [markdown]
# **(0.1 балл) (?)** Проанализируйте полученный результат. Согласуются ли полученные результаты с теми, что мы обсуждали на семинарах (с комментарием)?
#
# __Your answer here:__ Да, согласуются.\
# Логистическая регрессия линейная (слишком лёгкая) модель. Поэтому она не дообучаетя, в связи с этим у неё большое смещение и маленький разброс. Из-за того, что скорее всего наши данные имеют не линейную зависимость,  она плохо их приближает ($\Rightarrow bias$ растёт).\
# Деревья же уже лучше обучаются, поэтому они хорошо приближают данные. Т.е. смещение уменьшается. Но при этом они имеют свойство сильно переобучаться(чувствительны к входным данным). И из-за этого разброс сильно увеличивается.\
# Лес помогает решить данную проблему деревьев, бутстрапируя данную выборку и увеличивая число деревьев. Поэтому разброс уменьшаеся.
#
# **(0.1 балл) (?)** Вспомните во сколько раз в теории бутстрап уменьшает разброс базового алгоритма. Выполняется ли это в ваших экспериментах? Если нет, поясните, почему.
#
# __Your answer here:__ В теории бустрап уменьшает разброс базового алгоритма в N раз, где N-число бутстрап-выборок. Заметим, что у нас получилось отношение разбросов для дерева и леса примерно 6. Но по дефолту в лесе стоит 100 деревьев. То есть разброс должен был уменьшиться в 100 раз. Чего не произошло в наших экспериментах. Возможно это связано  с тем, что в теории предполагается, что все выборки некоррелированы между собой. Но на практике из-за малого признакого пространства скорее всего так не будет, поэтому разброс сократится в меньшее число раз. Так же на это может повлиять, что у нас слишком мало данных.

# %% [markdown]
# ### Визуализация предсказаний базовых алгоритмов бэггинга
#
# В материалах лекций можно найти изображение, похожее на мишень - визуализация алгоритмов с разным смещением и разным разбросом. В центре "мишени" - правильный ответ, а "попадания" - предсказания алгоритмов, обученных по разным выборкам. Построим похожее изображение на наших данных для трех алгоритмов. Наши "мишени" будут одномерными, потому что мы решаем задачу одномерной регрессии.
#
# __Задание 3. (1.5 балла)__
#
# **(0.5 балла)** Реализуйте фукнцию plot_predictions. Она должна выполнять следующие действия:
# 1. Случайно выбрать num_test_objects пар объект-целевая переменная из выборки X, y. Получится две выборки: маленькая X_test, y_test (выбранные тестовые объекты) и X_train, y_train (остальные объекты).
# 1. Сгенерировать num_runs выборок методом бутстарапа из X_train, y_train. На каждой выборке обучить алгоритм regressor и сделать предсказания для X_test.
# 1. Нарисовать scatter-график. По оси абсцисс - объекты тестовой выборки (номера от 0 до num_test_objects-1), по оси ординат - предсказания для каждого из num_runs выборок. В итоге получится num_test_objects столбиков с точками. Для каждого тестового объекта надо отметить одним цветом (в рамках каждого номера объекта, т.е. предсказания для объектов с одинаковым номером -- одинаковым цветом, а с разными -- разными цветами) все предсказания для него, а также черным цветом отметить правильный ответ.
# 1. Подпишите оси и название графика (аргумент title).

# %%
from sklearn.model_selection import train_test_split

# %%
def plot_predictions(regressor, X, y, num_runs=100, num_test_objects=10, title=""):
    """
    plot graphics described above
    """
    ### your code here ╰( ͡° ͜ʖ ͡° )つ──☆*:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=num_test_objects, random_state=10)
    y_pred = np.zeros([num_test_objects, num_runs])
    
    for i in range(num_runs):
        boot_idx = np.random.randint(0, X_train.shape[0], X_train.shape[0])
        X_boot, y_boot = X_train[boot_idx], y_train[boot_idx]
        
        regressor.fit(X_boot, y_boot)
        y_pred[:, i] = regressor.predict(X_test)
    
    plt.title(title, fontsize=15)
    plt.xlabel('Объекты тестовой выборки', fontsize=15)
    plt.ylabel('Предсказания каждого бутстрапа', fontsize=15)
    plt.grid(True)
    plt.ylim((9, 52))
    
    for i in range(num_test_objects):
        plt.scatter([i]*num_runs, y_pred[i], label = i)
        plt.scatter(i, y_test[i], c = 'black')

# %% [markdown]
# **(0.5 баллa)** Нарисуйте графики для линейной регрессии, решающего дерева и случайного леса. Нарисуйте три графика в строчку (это можно сделать с помощью plt.subplot) с одинаковой осью ординат (это важно для понимания масштаба разброса у разных алгоритмов):

# %%
plt.figure(figsize=(20, 9))

plt.subplot(1, 3, 1)
plot_predictions(LinearRegression(), X, y, title='LinearRegression')

plt.subplot(1, 3, 2)
plot_predictions(DecisionTreeRegressor(), X, y, title='DecisionTreeRegressor')

plt.subplot(1, 3, 3)
plot_predictions(RandomForestRegressor(), X, y, title='RandomForestRegressor')

# %% [markdown]
# **(0.5 балла) (?)** Для каждого графика прокомментируйте, как он характеризует смещение и разброс соответствующего алгоритма.
#
# **Your answer here:** Смещение - это расстояние от предсказаной точки до чёрной. А разброс - расстояние между точками своего типа.\
# Видим, что у линейной модели, есть случаи с очень большим смещением (6, 2, 3, 8 объекты). Но группки довольно сильно прижаты, что говорит о небольшом разбросе.\
# Напротив, в деревьях наши кучки стали более вытянутые (т.е. мы наблюдаем большой разброс). Но при этом модель стала лучше предсказывать данные. Чёрные точки в основном находятся близко к центрам групп (смещение уменьшилось).\
# Лес объединяет плюсы предыдущих моделей: кучки более сжаты ($variance$ маленький), чёрные точки располагаются в своих группах ($bias$ небольшой).

# %% [markdown]
# ### Часть 2. Градиентный бустинг

# %% [markdown]
# **Задание 4 (1 балл)**
#
# Мы будем использовать данные из [соревнования](https://www.kaggle.com/t/b710e05dc0bd424995ca94da5b639869) (вам нужны только данные, посылать туда ничего не надо).
# * Загрузите таблицу application_train.csv;
# * Запишите в Y столбец с целевой переменной (TARGET);
# * Удалите ненужные столбцы:
#     * Воспользуйтесь описанием соревнования
#     * При желании, воспользуйтесь методами feature selection/стат. методами, если хотите. Объясните, что использовали и почему решили выкинуть тот или иной признак.
# * Определите тип столбцов и заполните пропуски - стратегия произвольная;
# * Разбейте выборку в соотношении 70:30 с random_state=0. Если считаете нужным, сделайте сбалансированное по классам разбиение.
#
# Так как в данных имеется значительный дисбаланс классов, в качестве метрики качества везде будем использовать площадь под precision-recall кривой (AUC-PR).

# %%
from sklearn.metrics import roc_auc_score, precision_recall_curve, plot_roc_curve
from sklearn.metrics import plot_precision_recall_curve, average_precision_score

# %%
data = pd.read_csv('application_train.csv', index_col=0)
target = data.TARGET.values
data = data.drop('TARGET', axis=1)

# %%
data
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 247330             Cash loans           F            N               N
# 425716             Cash loans           F            Y               Y
# 331625             Cash loans           M            Y               Y
# 455397        Revolving loans           F            N               Y
# 449114             Cash loans           F            N               Y
# ...                       ...         ...          ...             ...
# 239009             Cash loans           F            N               Y
# 399937             Cash loans           F            N               N
# 253016             Cash loans           M            Y               Y
# 270275        Revolving loans           M            Y               Y
# 241394             Cash loans           M            Y               Y
#
#             CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# ...

# %%
numeric_data = data.select_dtypes([np.number])
numeric_data_mean = numeric_data.mean()
numeric_features = numeric_data.columns
numeric_features.shape
# Out:
# (104,)

# %% [markdown]
# Удалим некторые признаки из нашей выборки. Поступим аналогично методу VarianceThreshold из sklearn.feature_selection, который выкидывает признаки с маленьким разбросом. Т.е. которые почти всюду принимают одно и то же значение. Удалим те признаки, у которых диспресия меньше 0.001.

# %%
del_num = numeric_features[(data.std() < np.sqrt(0.001))]

# %%
data = data.drop(del_num, axis=1)

# %%
numeric_data = data.select_dtypes([np.number])
numeric_data_mean = numeric_data.mean()
numeric_features = numeric_data.columns
numeric_features.shape
# Out:
# (93,)

# %%
data.dtypes # типы столбцов
# Out:
# NAME_CONTRACT_TYPE             object
# CODE_GENDER                    object
# FLAG_OWN_CAR                   object
# FLAG_OWN_REALTY                object
# CNT_CHILDREN                    int64
#                                ...
# AMT_REQ_CREDIT_BUREAU_DAY     float64
# AMT_REQ_CREDIT_BUREAU_WEEK    float64
# AMT_REQ_CREDIT_BUREAU_MON     float64
# AMT_REQ_CREDIT_BUREAU_QRT     float64
# AMT_REQ_CREDIT_BUREAU_YEAR    float64
# Length: 109, dtype: object

# %%
int_features = []
for feat in data.columns[data.dtypes == 'int64']:
    int_features += [feat]
int_features, len(int_features)
# Out:
# (['CNT_CHILDREN',
#   'DAYS_BIRTH',
#   'DAYS_EMPLOYED',
#   'DAYS_ID_PUBLISH',
#   'FLAG_EMP_PHONE',
#   'FLAG_WORK_PHONE',
#   'FLAG_CONT_MOBILE',
#   'FLAG_PHONE',
#   'FLAG_EMAIL',
#   'REGION_RATING_CLIENT',
#   'REGION_RATING_CLIENT_W_CITY',
#   'HOUR_APPR_PROCESS_START',
#   'REG_REGION_NOT_LIVE_REGION',
#   'REG_REGION_NOT_WORK_REGION',
#   'LIVE_REGION_NOT_WORK_REGION',
#   'REG_CITY_NOT_LIVE_CITY',
#   'REG_CITY_NOT_WORK_CITY',
#   'LIVE_CITY_NOT_WORK_CITY',
#   'FLAG_DOCUMENT_3',
#   'FLAG_DOCUMENT_5',
#   'FLAG_DOCUMENT_6',
#   'FLAG_DOCUMENT_8',
#   'FLAG_DOCUMENT_9',
#   'FLAG_DOCUMENT_11',
#   'FLAG_DOCUMENT_13',
#   'FLAG_DOCUMENT_14',
#   'FLAG_DOCUMENT_15',
#   'FLAG_DOCUMENT_16',
#   'FLAG_DOCUMENT_18'],
#  29)

# %%
num_features = list(numeric_features)

for feat in int_features:
    num_features.remove(feat)

num_features, len(num_features)
# Out:
# (['AMT_INCOME_TOTAL',
#   'AMT_CREDIT',
#   'AMT_ANNUITY',
#   'AMT_GOODS_PRICE',
#   'DAYS_REGISTRATION',
#   'OWN_CAR_AGE',
#   'CNT_FAM_MEMBERS',
#   'EXT_SOURCE_1',
#   'EXT_SOURCE_2',
#   'EXT_SOURCE_3',
#   'APARTMENTS_AVG',
#   'BASEMENTAREA_AVG',
#   'YEARS_BEGINEXPLUATATION_AVG',
#   'YEARS_BUILD_AVG',
#   'COMMONAREA_AVG',
#   'ELEVATORS_AVG',
#   'ENTRANCES_AVG',
#   'FLOORSMAX_AVG',
#   'FLOORSMIN_AVG',
#   'LANDAREA_AVG',
#   'LIVINGAPARTMENTS_AVG',
#   'LIVINGAREA_AVG',
#   'NONLIVINGAPARTMENTS_AVG',
#   'NONLIVINGAREA_AVG',
#   'APARTMENTS_MODE',
#   'BASEMENTAREA_MODE',
#   'YEARS_BEGINEXPLUATATION_MODE',
#   'YEARS_BUILD_MODE',
#   'COMMONAREA_MODE',
#   'ELEVATORS_MODE',
#   'ENTRANCES_MODE',
#   'FLOORSMAX_MODE',
#   'FLOORSMIN_MODE',
#   'LANDAREA_MODE',
#   'LIVINGAPARTMENTS_MODE',
#   'LIVINGAREA_MODE',
#   'NONLIVINGAPARTMENTS_MODE',
#   'NONLIVINGAREA_MODE',
#   'APARTMENTS_MEDI',
#   'BASEMENTAREA_MEDI',
#   'YEARS_BEGINEXPLUATATION_MEDI',
# ...

# %%
cat_features = list(data.dtypes[data.dtypes == "object"].index)
cat_features, len(cat_features)
# Out:
# (['NAME_CONTRACT_TYPE',
#   'CODE_GENDER',
#   'FLAG_OWN_CAR',
#   'FLAG_OWN_REALTY',
#   'NAME_TYPE_SUITE',
#   'NAME_INCOME_TYPE',
#   'NAME_EDUCATION_TYPE',
#   'NAME_FAMILY_STATUS',
#   'NAME_HOUSING_TYPE',
#   'OCCUPATION_TYPE',
#   'WEEKDAY_APPR_PROCESS_START',
#   'ORGANIZATION_TYPE',
#   'FONDKAPREMONT_MODE',
#   'HOUSETYPE_MODE',
#   'WALLSMATERIAL_MODE',
#   'EMERGENCYSTATE_MODE'],
#  16)

# %%
len(cat_features) + len(num_features) + len(int_features)
# Out:
# 109

# %%
data.isna().sum()[data.isna().sum() > 0]
# Out:
# AMT_ANNUITY                        8
# AMT_GOODS_PRICE                  199
# NAME_TYPE_SUITE                  913
# OWN_CAR_AGE                   141836
# OCCUPATION_TYPE                67409
#                                ...
# AMT_REQ_CREDIT_BUREAU_DAY      29150
# AMT_REQ_CREDIT_BUREAU_WEEK     29150
# AMT_REQ_CREDIT_BUREAU_MON      29150
# AMT_REQ_CREDIT_BUREAU_QRT      29150
# AMT_REQ_CREDIT_BUREAU_YEAR     29150
# Length: 67, dtype: int64

# %% [markdown]
# Заменим пропуски в численных вещественных признаках на среднее, в категориальных на новую категорию "NotGiven".

# %%
numeric_data[int_features].isna().sum()[numeric_data[int_features].isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# В численных целых нет пропусков, поэтому оставим их.

# %%
data[cat_features] = data[cat_features].fillna("NotGiven")
numeric_data_mean = numeric_data[num_features].mean()
data[num_features] = data[num_features].fillna(numeric_data_mean)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=0)

# %%
X_train
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 225148             Cash loans           F            N               Y
# 171380             Cash loans           F            N               Y
# 175401             Cash loans           M            N               Y
# 447108             Cash loans           F            N               Y
# 270357             Cash loans           M            N               Y
# ...                       ...         ...          ...             ...
# 264986             Cash loans           F            Y               Y
# 355746             Cash loans           F            N               Y
# 193714             Cash loans           F            N               Y
# 442029             Cash loans           M            Y               Y
# 118573             Cash loans           F            N               Y
#
#             CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# ...

# %% [markdown]
# **Задание 5 (1 балл)**

# %% [markdown]
# **(0.7 баллa)** Обучите реализации градиентного бустинга LightGBM и Catboost на вещественных признаках без подбора параметров.
#
# **(0.3 баллa) (?) Получилась ли заметная разнциа в качестве? Как вы думаете, почему?**
#
# **Замечание:**
# * В этом и последующих экспериментах необходимо измерять время обучения моделей.

# %%
from catboost import CatBoostClassifier

# %%
# %%time
clf_cat = CatBoostClassifier()
clf_cat.fit(X_train[numeric_features], y_train)
y_pred_catboost = clf_cat.predict_proba(X_test[numeric_features])[:, 1]
# Out:
# Learning rate set to 0.087693
# 0:	learn: 0.6042252	total: 24.7ms	remaining: 24.7s
# 1:	learn: 0.5352832	total: 49.8ms	remaining: 24.9s
# 2:	learn: 0.4832714	total: 71.5ms	remaining: 23.8s
# 3:	learn: 0.4393097	total: 98.6ms	remaining: 24.5s
# 4:	learn: 0.4043625	total: 125ms	remaining: 24.8s
# 5:	learn: 0.3749882	total: 151ms	remaining: 25s
# 6:	learn: 0.3535481	total: 175ms	remaining: 24.8s
# 7:	learn: 0.3364622	total: 203ms	remaining: 25.1s
# 8:	learn: 0.3221777	total: 233ms	remaining: 25.6s
# 9:	learn: 0.3116226	total: 260ms	remaining: 25.7s
# 10:	learn: 0.3020075	total: 286ms	remaining: 25.7s
# 11:	learn: 0.2947374	total: 311ms	remaining: 25.6s
# 12:	learn: 0.2883438	total: 337ms	remaining: 25.6s
# 13:	learn: 0.2826492	total: 366ms	remaining: 25.8s
# 14:	learn: 0.2786606	total: 393ms	remaining: 25.8s
# 15:	learn: 0.2747169	total: 426ms	remaining: 26.2s
# 16:	learn: 0.2722259	total: 451ms	remaining: 26.1s
# 17:	learn: 0.2696622	total: 481ms	remaining: 26.2s
# ...

# %%
print(f'CatBoost РR-AUC: {average_precision_score(y_test, y_pred_catboost)}')
# Out:
# CatBoost РR-AUC: 0.23703551110564508

# %%
from lightgbm import LGBMClassifier

# %%
# %%time
clf_lgbm = LGBMClassifier()
clf_lgbm.fit(X_train[numeric_features], y_train)
y_proba_lgbm = clf_lgbm.predict_proba(X_test[numeric_features])[:, 1]
# Out:
# Wall time: 2.75 s

# %%
print(f'LGBMClassifier PR-AUC: {average_precision_score(y_test, y_proba_lgbm)}')
# Out:
# LGBMClassifier PR-AUC: 0.23808999456583338

# %% [markdown]
# **Your answer here:** Особой разницы в качестве классификации не наблюдается. Скорее всего это связано с тем, что каждая реализация бустинга повзаимствовала у другой все самые классные идеи, поэтому они выдают примерно одинаковый результат. Но время их работы существенно отличается... CatBoost работает дольше почти  в 10 раз...

# %% [markdown]
# __Задание 6. (2 балла)__
#
# **(1.5 баллa)** Подберите оптимальные с точки зрения метрики качества параметры алгоритмов, изменяя:
#
# * глубину деревьев;
# * количество деревьев;
# * темп обучения;
#
# Масштаб значений предлагается посмотреть [тут](https://github.com/esokolov/ml-course-hse/blob/master/2019-fall/seminars/sem10-gbm.ipynb).
#
# **(0.5 баллa) (?)** Проанализируйте соотношения получившихся оптимальных глубины и количества деревьев в зависимости от алгоритма.**
#
# **Если на перебор гиперпараметров уходит много времени, то переберите значениях каких-нибудь 1-2 гиперпараметров, а не всех предложенных 3**

# %% [markdown]
# Подбирать будем по специальной отложенной выборке.

# %%
X_train_boost, X_val, y_train_boost, y_val = train_test_split(X_train[numeric_features], y_train, test_size=0.2, random_state=0)

# %% [markdown]
# Сначала выберем наилучшее количество деревьев, оставив остальные признаки по умолчанию.

# %%
def plot_num_estimators(CatBoost_features, LGBM_features, cat_features=None):
    n_trees = [1, 5, 10, 100, 200, 300, 400, 500, 700, 1000, 2000]
    quals_train_cat = []
    quals_test_cat = []
    quals_train_lgb = []
    quals_test_lgb = []
    
    X_train_cat, X_val_cat, y_train_cat, y_val_cat = CatBoost_features
    X_train_lgbm, X_val_lgbm, y_train_lgbm, y_val_lgbm = LGBM_features
    
    for n in n_trees:
        clf = CatBoostClassifier(cat_features = cat_features, n_estimators=n, logging_level='Silent')
        clf.fit(X_train_cat, y_train_cat)

        lgb = LGBMClassifier(n_estimators=n)
        lgb.fit(X_train_lgbm, y_train_lgbm)

        q_train = average_precision_score(y_train_cat, clf.predict_proba(X_train_cat)[:, 1])
        q_test = average_precision_score(y_val_cat, clf.predict_proba(X_val_cat)[:, 1])
        quals_train_cat.append(q_train)
        quals_test_cat.append(q_test)

        q_train = average_precision_score(y_train_lgbm, lgb.predict_proba(X_train_lgbm)[:, 1])
        q_test = average_precision_score(y_val_lgbm, lgb.predict_proba(X_val_lgbm)[:, 1])
        quals_train_lgb.append(q_train)
        quals_test_lgb.append(q_test)

    plt.figure(figsize=(20, 7))
    plt.subplot(1, 2, 1)
    plt.plot(n_trees, quals_train_cat, marker='.', label='train')
    plt.plot(n_trees, quals_test_cat, marker='.', label='val')

    plt.title('Зависимость PR-AUC CatBoost от количества деревьев', fontsize=14)
    plt.xlabel('Количество деревьев', fontsize=14)
    plt.ylabel('PR-AUC', fontsize=14)
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(n_trees, quals_train_lgb, marker='.', label='train')
    plt.plot(n_trees, quals_test_lgb, marker='.', label='val')

    plt.title('Зависимость PR-AUC LGBM от количества деревьев', fontsize=14)
    plt.xlabel('Количество деревьев', fontsize=14)
    plt.ylabel('PR-AUC', fontsize=14)
    plt.legend()
    plt.grid(True)

# %%
cat = (X_train_boost, X_val, y_train_boost, y_val)
plot_num_estimators(cat, cat)

# %% [markdown]
# Видим, что при малом количестве деревьев модель не успевает исправить ошибки предыдущих алгоритмов, поэтому качество довольное низкое, как на трейне, так и на валидации.\
# С увеличением $n\_estimators$ PR-AUС заметно увеличивается для CatBoost. После 200 на валидации качество перестаёт заметно увеличиваться, а после 700 так и вовсе не меняется. Заметим, что модель переобучается под обучающую подвыборку (PR-AUC на трейне лучше больше чем на 0.25). Всюду далее для CatBoost будем брать $n\_estimators = 700$.\
# Ситуация с LGBM выглядит аналогично. Наилучшее качество на валидации достигается при $n\_estimators = 100$. Его мы и будем дальше использовать. Заметим, что модель LGBM, намного сильнее переобучается. Причём, с увеличением $n\_estimators$ качество начинает снижаться (на тесте).

# %% [markdown]
# Теперь посмотрим на результаты работы бустинга в зависимости от глубины дерева.

# %%
def plot_max_depth(CatBoost_mat, LGBM_mat, n_estimators, cat_features=None):
    depth = list(range(1, 12, 2))
    n_trees_cat, n_trees_lgbm = n_estimators

    quals_train_cat = []
    quals_test_cat = []
    quals_train_lgb = []
    quals_test_lgb = []
    
    X_train_cat, X_val_cat, y_train_cat, y_val_cat = CatBoost_mat
    X_train_lgbm, X_val_lgbm, y_train_lgbm, y_val_lgbm = LGBM_mat
    
    for d in depth:
        clf = CatBoostClassifier(n_estimators=n_trees_cat, max_depth=d,
                                 cat_features = cat_features, logging_level="Silent")
        clf.fit(X_train_cat, y_train_cat)

        lgb = LGBMClassifier(n_estimators=n_trees_lgbm, max_depth=d)
        lgb.fit(X_train_lgbm, y_train_lgbm)

        q_train = average_precision_score(y_train_cat, clf.predict_proba(X_train_cat)[:, 1])
        q_test = average_precision_score(y_val_cat, clf.predict_proba(X_val_cat)[:, 1])
        quals_train_cat.append(q_train)
        quals_test_cat.append(q_test)

        q_train = average_precision_score(y_train_lgbm, lgb.predict_proba(X_train_lgbm)[:, 1])
        q_test = average_precision_score(y_val_lgbm, lgb.predict_proba(X_val_lgbm)[:, 1])
        quals_train_lgb.append(q_train)
        quals_test_lgb.append(q_test)

    plt.figure(figsize=(20, 7))

    plt.subplot(1, 2, 1)
    plt.plot(depth, quals_train_cat, marker='.', label='train')
    plt.plot(depth, quals_test_cat, marker='.', label='val')

    plt.title('Зависимость PR-AUC CatBoost от глубины деревьев', fontsize=14)
    plt.xlabel('Глубина деревьев', fontsize=14)
    plt.ylabel('PR-AUC', fontsize=14)
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(depth, quals_train_lgb, marker='.', label='train')
    plt.plot(depth, quals_test_lgb, marker='.', label='val')

    plt.title('Зависимость PR-AUC LGBM от глубины деревьев', fontsize=14)
    plt.xlabel('Глубина деревьев', fontsize=14)
    plt.ylabel('PR-AUC', fontsize=14)
    plt.legend()
    plt.grid(True)

# %%
cat = (X_train_boost, X_val, y_train_boost, y_val)
plot_max_depth(cat, cat, (700, 100))

# %% [markdown]
# Видно, что чем больше глубина деревьев, тем сильнее модели переобучаются. Это можно объяснить тем, что каждое последующее дерево будет довольно сложным. Следовательно оно будет лучше исправлять ошибки предыдущих деревьев. Таким образом, наша модель будет очень сильно подстраиваться под обучающую выборку.  На обучающей выборке точность достигает практически 1 (CatBoost). Но на валидационной дела обстоят намного хуже. Наилучшим значением глубины дерева, является 3 (CatBoost) и 9 (LGBM). Эти значения мы и будем всюду дальше брать.

# %% [markdown]
# Теперь посмотрим как бустинг проявит себя в зависимости от темпа обучения

# %%
def plot_lr(CatBoost_mat, LGBM_mat, n_estimators, max_depth, cat_features=None):
    learning_rate = np.logspace(-4, 0, 10)
    depth_cat, depth_lgbm = max_depth
    n_trees_cat, n_trees_lgbm = n_estimators
    
    X_train_cat, X_val_cat, y_train_cat, y_val_cat = CatBoost_mat
    X_train_lgbm, X_val_lgbm, y_train_lgbm, y_val_lgbm = LGBM_mat
    
    quals_train_cat = []
    quals_test_cat = []
    quals_train_lgb = []
    quals_test_lgb = []

    for lr in learning_rate:
        clf = CatBoostClassifier(n_estimators=n_trees_cat, max_depth=depth_cat, 
                             learning_rate = lr, cat_features = cat_features, logging_level="Silent")
        clf.fit(X_train_cat, y_train_cat)

        lgb = LGBMClassifier(n_estimators=n_trees_lgbm, max_depth=d, learning_rate = lr)
        lgb.fit(X_train_lgbm, y_train_lgbm)

        q_train = average_precision_score(y_train_cat, clf.predict_proba(X_train_cat)[:, 1])
        q_test = average_precision_score(y_val_cat, clf.predict_proba(X_val_cat)[:, 1])
        quals_train_cat.append(q_train)
        quals_test_cat.append(q_test)

        q_train = average_precision_score(y_train_lgbm, lgb.predict_proba(X_train_lgbm)[:, 1])
        q_test = average_precision_score(y_val_lgbm, lgb.predict_proba(X_val_lgbm)[:, 1])
        quals_train_lgb.append(q_train)
        quals_test_lgb.append(q_test)

    plt.figure(figsize=(17, 6))

    plt.subplot(1, 2, 1)
    plt.plot(learning_rate, quals_train_cat, marker='.', label='train')
    plt.plot(learning_rate, quals_test_cat, marker='.', label='val')

    plt.title('Зависимость PR-AUC CatBoost от learning_rate', fontsize=14)
    plt.xlabel('learning_rate', fontsize=14)
    plt.xscale("log")
    plt.ylabel('PR-AUC', fontsize=14)
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(learning_rate, quals_train_lgb, marker='.', label='train')
    plt.plot(learning_rate, quals_test_lgb, marker='.', label='val')

    plt.title('Зависимость PR-AUC LGBM от learning_rate', fontsize=14)
    plt.xlabel('learning_rate', fontsize=14)
    plt.xscale("log")
    plt.ylabel('PR-AUC', fontsize=14)
    plt.legend()
    plt.grid(True)

# %%
cat = (X_train_boost, X_val, y_train_boost, y_val)
plot_lr(cat, cat, (700, 100), (3, 9))

# %%
np.logspace(-4, 0, 10)
# Out:
# array([1.00000000e-04, 2.78255940e-04, 7.74263683e-04, 2.15443469e-03,
#        5.99484250e-03, 1.66810054e-02, 4.64158883e-02, 1.29154967e-01,
#        3.59381366e-01, 1.00000000e+00])

# %% [markdown]
# Заметим, что при слишком маленьком $learning\_rate$ качество немного хуже. А при слишком большом оно вообще сильно падает. Даже на обучающей выборке (в случае с LGBM). то можно объснить тем, что каждое последующее дерево исправляет ошибки предыдущих. Тем самым при очень маленьком $learning\_rate$ этот "вклад" новых деревьев почти не будет учитываться. Т.е. ошибки, произошедшие на прошлой итерации, практически не будут исправляться. Однако при слишком большом значении этого параметра модель будет уделять большее внимание новым деревьям, которые заточены только на ошибки, но не на правильные ответы предыдущих. Следовательно, модель в меньшей степени будет учитывать "правильность" предыдущих методов. Таким образом, темп обучения должен быть не сильно маленьким, но и не большим. Оптимальным значением $learning\_rate$ оказалось примерно 0.046

# %% [markdown]
# Обучим теперь наши модели на подобранных параметрах:\
# **CatBoost:** $n\_estimators = 700, max\_depth = 3, learning\_rate = 0.046$\
# **LGBM:** $n\_estimators = 100, max\_depth = 9, learning\_rate = 0.046$

# %%
# %%time
clf_cat = CatBoostClassifier(n_estimators=700, max_depth=3, learning_rate = 4.64158883e-02)
clf_cat.fit(X_train[numeric_features], y_train)
y_proba_catboost = clf_cat.predict_proba(X_test[numeric_features])[:, 1]
# Out:
# 0:	learn: 0.6455400	total: 31.5ms	remaining: 22s
# 1:	learn: 0.6031616	total: 55.8ms	remaining: 19.5s
# 2:	learn: 0.5656941	total: 78ms	remaining: 18.1s
# 3:	learn: 0.5338758	total: 100ms	remaining: 17.4s
# 4:	learn: 0.5056409	total: 122ms	remaining: 16.9s
# 5:	learn: 0.4790326	total: 144ms	remaining: 16.6s
# 6:	learn: 0.4570812	total: 168ms	remaining: 16.7s
# 7:	learn: 0.4358246	total: 191ms	remaining: 16.5s
# 8:	learn: 0.4180954	total: 213ms	remaining: 16.4s
# 9:	learn: 0.4021124	total: 243ms	remaining: 16.7s
# 10:	learn: 0.3879064	total: 273ms	remaining: 17.1s
# 11:	learn: 0.3759058	total: 296ms	remaining: 17s
# 12:	learn: 0.3634468	total: 320ms	remaining: 16.9s
# 13:	learn: 0.3532167	total: 343ms	remaining: 16.8s
# 14:	learn: 0.3439784	total: 368ms	remaining: 16.8s
# 15:	learn: 0.3361335	total: 390ms	remaining: 16.7s
# 16:	learn: 0.3295992	total: 416ms	remaining: 16.7s
# 17:	learn: 0.3225076	total: 441ms	remaining: 16.7s
# 18:	learn: 0.3160583	total: 467ms	remaining: 16.7s
# ...

# %%
print(f'CatBoost РR-AUC: {average_precision_score(y_test, y_proba_catboost)}')
# Out:
# CatBoost РR-AUC: 0.24405225723140156

# %%
# %%time
clf_lgbm = LGBMClassifier(n_estimators=100, max_depth=9, lerning_rate = 4.64158883e-02)
clf_lgbm.fit(X_train[numeric_features], y_train)
y_proba_lgbm = clf_lgbm.predict_proba(X_test[numeric_features])[:, 1]
# Out:
# [LightGBM] [Warning] Unknown parameter: lerning_rate
# Wall time: 2.48 s

# %%
print(f'LGBM РR-AUC: {average_precision_score(y_test, y_proba_lgbm)}')
# Out:
# LGBM РR-AUC: 0.24009196016454473

# %% [markdown]
# **Your answer here:** Заметим, что LGBM нужно гораздо меньше деревьев (в 7 раз), но при этом они должны быть глубже (в 3 раза). Видно, что качество работы модели CatBoost заметно увеличилось, а время уменьшилось. Но всё же он работает в несколько раз медленнее LGBM. Для него точность повысилась, но не так сильно.

# %% [markdown]
# **Задание 7 (1.5 баллa)**
#
# **(1 балл)** Добавьте категориальные признаки к вещественным следующими способами:
#
# * как OHE признаки;
# * как счетчики со сглаживанием.
#
# Можно использовать библиотечные реализации; при подсчете счетчиков нельзя использовать циклы.
#
# **(0.5 баллa) (?)** Как меняется время, необходимое для обучения моделей в зависимости от способа кодирования? (Параметры можно не подбирать).

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
for cat in cat_features:
    i = np.arange(X_train.shape[0])
    for c in np.unique(X_train[cat]):
        if c not in np.unique(X_test[cat]):
            idx = X_train[cat][X_train[cat] == c].index.values
            X_test = X_test.append(X_train.loc[idx], ignore_index=False)
            i_new = i[X_train[cat] == c]
            y_test = np.append(y_test, y_train[i_new])
    
    i = np.arange(X_test.shape[0])     
    for c in np.unique(X_test[cat]):
        if c not in np.unique(X_train[cat]):
            idx = X_test[cat][X_test[cat] == c].index.values
            X_train = X_train.append(X_test.loc[idx], ignore_index=False)
            i_new = i[X_test[cat] == c]
            y_train = np.append(y_train, y_test[i_new])

# %%
X_train.shape, X_test.shape, len(y_test), len(y_train)
# Out:
# ((150681, 109), (64582, 109), 64582, 150681)

# %%
ohe = OneHotEncoder(sparse=False)
cat_ohe_train = ohe.fit_transform(X_train[cat_features])
cat_ohe_test = ohe.transform(X_test[cat_features])

# %%
cat_ohe_train.shape, cat_ohe_test.shape, X_train[numeric_features].shape
# Out:
# ((150681, 146), (64582, 146), (150681, 93))

# %%
X_train_ohe = np.concatenate((cat_ohe_train, X_train[numeric_features]), axis=1)
X_test_ohe = np.concatenate((cat_ohe_test, X_test[numeric_features]), axis=1)

# %%
X_train_ohe.shape, X_test_ohe.shape
# Out:
# ((150681, 239), (64582, 239))

# %%
# %%time
clf_cat = CatBoostClassifier(n_estimators=700, max_depth=3, learning_rate = 4.64158883e-02)
clf_cat.fit(X_train_ohe, y_train)
y_proba_catboost = clf_cat.predict_proba(X_test_ohe)[:, 1]
# Out:
# 0:	learn: 0.6458351	total: 54.9ms	remaining: 38.4s
# 1:	learn: 0.6034524	total: 91ms	remaining: 31.8s
# 2:	learn: 0.5660284	total: 124ms	remaining: 28.8s
# 3:	learn: 0.5320643	total: 157ms	remaining: 27.3s
# 4:	learn: 0.5036807	total: 193ms	remaining: 26.9s
# 5:	learn: 0.4787891	total: 229ms	remaining: 26.5s
# 6:	learn: 0.4561582	total: 259ms	remaining: 25.6s
# 7:	learn: 0.4344823	total: 293ms	remaining: 25.3s
# 8:	learn: 0.4159154	total: 326ms	remaining: 25.1s
# 9:	learn: 0.4003851	total: 358ms	remaining: 24.7s
# 10:	learn: 0.3870717	total: 387ms	remaining: 24.2s
# 11:	learn: 0.3750780	total: 416ms	remaining: 23.9s
# 12:	learn: 0.3637226	total: 448ms	remaining: 23.7s
# 13:	learn: 0.3538101	total: 481ms	remaining: 23.6s
# 14:	learn: 0.3447209	total: 516ms	remaining: 23.6s
# 15:	learn: 0.3357069	total: 556ms	remaining: 23.8s
# 16:	learn: 0.3281109	total: 595ms	remaining: 23.9s
# 17:	learn: 0.3212021	total: 631ms	remaining: 23.9s
# 18:	learn: 0.3148132	total: 661ms	remaining: 23.7s
# ...

# %%
print(f'CatBoost РR-AUC: {average_precision_score(y_test, y_proba_catboost)}')
# Out:
# CatBoost РR-AUC: 0.24875404537698803

# %%
# %%time
clf_lgbm = LGBMClassifier(n_estimators=100, max_depth=9, learning_rate = 4.64158883e-02)
clf_lgbm.fit(X_train_ohe, y_train)
y_proba_lgbm = clf_lgbm.predict_proba(X_test_ohe)[:, 1]
# Out:
# Wall time: 2.82 s

# %%
print(f'LGBM РR-AUC: {average_precision_score(y_test, y_proba_lgbm)}')
# Out:
# LGBM РR-AUC: 0.2438547211599859

# %% [markdown]
# Теперь попробуем кодирование счетчиками со сглаживанием

# %%
from category_encoders.target_encoder import TargetEncoder

# %%
enc = TargetEncoder()
cat_count_train = enc.fit_transform(X_train[cat_features], y_train)
cat_count_test = enc.transform(X_test[cat_features])

# %%
X_train_count = np.concatenate((cat_count_train, X_train[numeric_features]), axis=1)
X_test_count = np.concatenate((cat_count_test, X_test[numeric_features]), axis=1)

# %%
X_train_count.shape, X_test_count.shape
# Out:
# ((150681, 109), (64582, 109))

# %%
# %%time
clf_cat = CatBoostClassifier(n_estimators=700, max_depth=3, learning_rate = 4.64158883e-02)
clf_cat.fit(X_train_count, y_train)
y_proba_catboost = clf_cat.predict_proba(X_test_count)[:, 1]
# Out:
# 0:	learn: 0.6457687	total: 328ms	remaining: 3m 49s
# 1:	learn: 0.6052186	total: 385ms	remaining: 2m 14s
# 2:	learn: 0.5693621	total: 469ms	remaining: 1m 49s
# 3:	learn: 0.5358672	total: 496ms	remaining: 1m 26s
# 4:	learn: 0.5075581	total: 534ms	remaining: 1m 14s
# 5:	learn: 0.4809842	total: 570ms	remaining: 1m 5s
# 6:	learn: 0.4582916	total: 601ms	remaining: 59.5s
# 7:	learn: 0.4376262	total: 646ms	remaining: 55.9s
# 8:	learn: 0.4193584	total: 675ms	remaining: 51.8s
# 9:	learn: 0.4030150	total: 699ms	remaining: 48.2s
# 10:	learn: 0.3885395	total: 720ms	remaining: 45.1s
# 11:	learn: 0.3749777	total: 747ms	remaining: 42.8s
# 12:	learn: 0.3638925	total: 769ms	remaining: 40.6s
# 13:	learn: 0.3535633	total: 796ms	remaining: 39s
# 14:	learn: 0.3446412	total: 821ms	remaining: 37.5s
# 15:	learn: 0.3360673	total: 850ms	remaining: 36.3s
# 16:	learn: 0.3280288	total: 878ms	remaining: 35.3s
# 17:	learn: 0.3209609	total: 904ms	remaining: 34.3s
# 18:	learn: 0.3148637	total: 940ms	remaining: 33.7s
# ...

# %%
print(f'CatBoost РR-AUC: {average_precision_score(y_test, y_proba_catboost)}')
# Out:
# CatBoost РR-AUC: 0.25016407027589976

# %%
# %%time
clf_lgbm = LGBMClassifier(n_estimators=100, max_depth=9, learning_rate = 4.64158883e-02)
clf_lgbm.fit(X_train_count, y_train)
y_proba_lgbm = clf_lgbm.predict_proba(X_test_count)[:, 1]
# Out:
# Wall time: 3.13 s

# %%
print(f'LGBM РR-AUC: {average_precision_score(y_test, y_proba_lgbm)}')
# Out:
# LGBM РR-AUC: 0.2450253789793749

# %% [markdown]
# **Your answer here:** Заметим, что при кодировке качество довольно сильно увеличивается. При OHE время работы CatBoost возросло практически в 2 раза, что неудивительно (т.к. довольно сильно увеличилось признаковое пространство). Но LGBM точно так же быстро выдал ответ.\
# При кодировке счётчиками со сглаживанием качество работы ещё сильнее увеличивается. А время работы остаётся примерно таким же, так как признаковое пространство имеет примерно ту же размерность, что и без кодирования.

# %% [markdown]
# **Задание 8 (1 балл)**
#
# **(0.7 баллa)** Для CatBoost можно не делать ручную обработку категориальных признаков, а подавать как есть. Обучите модель CatBoost, не обрабатывая специально категориальные признаки, замерьте время обучения (параметры возьмите из предыдущего пункта).
#
# **(0.3 баллa) (?)**Сравните с временем обучения модели CatBoost из предыдущего пункта. Как изменилось время? Почему?

# %%
# %%time
clf_cat = CatBoostClassifier(cat_features = cat_features, n_estimators=700, max_depth=3, learning_rate = 4.64158883e-02)
clf_cat.fit(X_train, y_train)
y_proba_catboost = clf_cat.predict_proba(X_test)[:, 1]
# Out:
# 0:	learn: 0.6476058	total: 203ms	remaining: 2m 21s
# 1:	learn: 0.6070408	total: 328ms	remaining: 1m 54s
# 2:	learn: 0.5694366	total: 441ms	remaining: 1m 42s
# 3:	learn: 0.5363613	total: 551ms	remaining: 1m 35s
# 4:	learn: 0.5065497	total: 642ms	remaining: 1m 29s
# 5:	learn: 0.4812985	total: 745ms	remaining: 1m 26s
# 6:	learn: 0.4592710	total: 838ms	remaining: 1m 22s
# 7:	learn: 0.4384928	total: 935ms	remaining: 1m 20s
# 8:	learn: 0.4200713	total: 1.03s	remaining: 1m 19s
# 9:	learn: 0.4039056	total: 1.13s	remaining: 1m 18s
# 10:	learn: 0.3894289	total: 1.22s	remaining: 1m 16s
# 11:	learn: 0.3768044	total: 1.32s	remaining: 1m 15s
# 12:	learn: 0.3639958	total: 1.41s	remaining: 1m 14s
# 13:	learn: 0.3539244	total: 1.51s	remaining: 1m 14s
# 14:	learn: 0.3445336	total: 1.6s	remaining: 1m 13s
# 15:	learn: 0.3361675	total: 1.71s	remaining: 1m 12s
# 16:	learn: 0.3287381	total: 1.79s	remaining: 1m 12s
# 17:	learn: 0.3222287	total: 1.9s	remaining: 1m 11s
# ...

# %%
print(f'CatBoost РR-AUC: {average_precision_score(y_test, y_proba_catboost)}')
# Out:
# CatBoost РR-AUC: 0.24596903405255216

# %% [markdown]
# **Your answer here:** Заметим, что качество работы чуть упало (скорее всего это связано с неудачным выбором гиперпараметров). Время довольно сильно возросло. Это связано со специальной работой с категориальными признаками, реализованной в CatBoost.

# %% [markdown]
# **Бонус. (1 балл)**
#
# **(0.7 баллa)**Подберите оптимальные параметры для LightGBM с вещественными и категориальными признаками (предварительно обработанные каким-нибудь способом). Подберите оптимальные параметры для CatBoost с вещественными и необработанными категориальными признаками.
#
# **(0.3 баллa) (?)**Сравните качество моделей на наилучших параметрах. Какой метод получился лучше с точки зрения качества? Совпадает ли результат с вашими ожиданиями?

# %% [markdown]
# Будем подбирать гиперпараметры в том же порядке, как мы это делали только для вещественных признаков.

# %% [markdown]
# Подберём сначала количество деревьев, зафиксировав остальные признаки по умолчанию.

# %%
X_train_cat, X_val_cat, y_train_cat, y_val_cat = train_test_split(X_train, y_train, test_size=0.2, random_state=0)
X_train_lgbm, X_val_lgbm, y_train_lgbm, y_val_lgbm = train_test_split(X_train_ohe, y_train, test_size=0.2, random_state=0)

# %%
cat = (X_train_cat, X_val_cat, y_train_cat, y_val_cat)
lgbm = (X_train_lgbm, X_val_lgbm, y_train_lgbm, y_val_lgbm )
plot_num_estimators(cat, lgbm, cat_features)

# %% [markdown]
# Тут можно заключить аналогичные выводы, как и в 6 задании. Будем далее брать $n\_estimators = 1000$ для CatBoost и 100 для LGBM.

# %% [markdown]
# Теперь подберём параметр max_depth.

# %%
cat = (X_train_cat, X_val_cat, y_train_cat, y_val_cat)
lgbm = (X_train_lgbm, X_val_lgbm, y_train_lgbm, y_val_lgbm )
plot_max_depth(cat, lgbm, (1000, 100), cat_features)

# %% [markdown]
# Результаты получились аналогичные. Берём $max\_depth = 5$ для CatBoost и 9 для LGBM.

# %% [markdown]
# Осталось подобрать только $learning\_rate$

# %%
plot_lr(cat, lgbm, (1000, 100), (5, 9), cat_features)

# %% [markdown]
# Обучим теперь наши модели на подобранных параметрах:\
# **CatBoost:** $n\_estimators = 1000, max\_depth = 5, learning\_rate = 0.046$

# %%
# %%time
clf_cat = CatBoostClassifier(cat_features = cat_features, n_estimators=1000, max_depth=5, learning_rate = 4.64158883e-02)
clf_cat.fit(X_train, y_train)
y_proba_catboost = clf_cat.predict_proba(X_test)[:, 1]
# Out:
# 0:	learn: 0.6475886	total: 170ms	remaining: 2m 49s
# 1:	learn: 0.6049152	total: 344ms	remaining: 2m 51s
# 2:	learn: 0.5673395	total: 517ms	remaining: 2m 51s
# 3:	learn: 0.5330048	total: 684ms	remaining: 2m 50s
# 4:	learn: 0.5035763	total: 834ms	remaining: 2m 45s
# 5:	learn: 0.4786477	total: 1.01s	remaining: 2m 47s
# 6:	learn: 0.4566474	total: 1.16s	remaining: 2m 44s
# 7:	learn: 0.4358510	total: 1.37s	remaining: 2m 50s
# 8:	learn: 0.4166013	total: 1.54s	remaining: 2m 49s
# 9:	learn: 0.3998748	total: 1.72s	remaining: 2m 50s
# 10:	learn: 0.3864446	total: 1.87s	remaining: 2m 48s
# 11:	learn: 0.3726526	total: 2.05s	remaining: 2m 48s
# 12:	learn: 0.3608356	total: 2.21s	remaining: 2m 47s
# 13:	learn: 0.3514737	total: 2.36s	remaining: 2m 45s
# 14:	learn: 0.3417895	total: 2.51s	remaining: 2m 44s
# 15:	learn: 0.3343380	total: 2.69s	remaining: 2m 45s
# 16:	learn: 0.3269492	total: 2.9s	remaining: 2m 47s
# 17:	learn: 0.3199112	total: 3.09s	remaining: 2m 48s
# ...

# %%
print(f'CatBoost РR-AUC: {average_precision_score(y_test, y_proba_catboost)}')
# Out:
# CatBoost РR-AUC: 0.25027192881374755

# %% [markdown]
# Заметим, что подобранные параметры для LGBM получились точно такие же как и раньше. Поэтому сейчас увеличим количество деревьев в 10 раз и посмотрим на качество.\
# **LGBM:** $n\_estimators = 1000, max\_depth = 9, learning\_rate = 0.046$

# %%
# %%time
clf_lgbm = LGBMClassifier(n_estimators=1000, max_depth=3, learning_rate = 4.64158883e-02)
clf_lgbm.fit(X_train_ohe, y_train)
y_proba_lgbm = clf_lgbm.predict_proba(X_test_ohe)[:, 1]
# Out:
# Wall time: 8.58 s

# %%
print(f'LGBM РR-AUC: {average_precision_score(y_test, y_proba_lgbm)}')
# Out:
# LGBM РR-AUC: 0.24797932982796142

# %% [markdown]
# Как видим качество работы моделей довольно сильно возросло. Для CatBoost точность получилась примерно такая же я, как и при кодировании счётчиками со сглаживанием. А для LGBM модели качество относительно сильно увеличилось (примерно на 0.003). Как и ожидалось CatBoost победил (Яндекс тащит еее).\
# Вместе с качеством увеличилось и время работы моделей (из-за увеличения числа деревьев и их глубины)...

# %% [markdown]
# Посмотрим, что будет, если увеличить количество деревьев в Catboost.

# %%
# %%time
clf_cat = CatBoostClassifier(cat_features = cat_features, n_estimators=2000, max_depth=3, learning_rate = 4.64158883e-02)
clf_cat.fit(X_train, y_train)
y_proba_catboost = clf_cat.predict_proba(X_test)[:, 1]
# Out:
# 0:	learn: 0.6476058	total: 213ms	remaining: 7m 4s
# 1:	learn: 0.6070408	total: 406ms	remaining: 6m 45s
# 2:	learn: 0.5694366	total: 594ms	remaining: 6m 35s
# 3:	learn: 0.5363613	total: 773ms	remaining: 6m 25s
# 4:	learn: 0.5065497	total: 961ms	remaining: 6m 23s
# 5:	learn: 0.4812985	total: 1.16s	remaining: 6m 25s
# 6:	learn: 0.4592710	total: 1.33s	remaining: 6m 19s
# 7:	learn: 0.4384928	total: 1.52s	remaining: 6m 17s
# 8:	learn: 0.4200713	total: 1.73s	remaining: 6m 23s
# 9:	learn: 0.4039056	total: 1.89s	remaining: 6m 15s
# 10:	learn: 0.3894289	total: 2.04s	remaining: 6m 8s
# 11:	learn: 0.3768044	total: 2.19s	remaining: 6m 2s
# 12:	learn: 0.3639958	total: 2.35s	remaining: 5m 59s
# 13:	learn: 0.3539244	total: 2.55s	remaining: 6m 1s
# 14:	learn: 0.3445336	total: 2.76s	remaining: 6m 4s
# 15:	learn: 0.3361675	total: 2.97s	remaining: 6m 8s
# 16:	learn: 0.3287381	total: 3.17s	remaining: 6m 9s
# 17:	learn: 0.3222287	total: 3.35s	remaining: 6m 8s
# ...

# %%
print(f'CatBoost РR-AUC: {average_precision_score(y_test, y_proba_catboost)}')
# Out:
# CatBoost РR-AUC: 0.2510893217360582

# %% [markdown]
# Качество увеличилось не очень замето (всего на 0.0008), зато время довольно сильно возросло. Так что оптимально использовать 1000 деревьев, приэтом теряя совсем чуть-чуть в качестве.

# %% [markdown]
# **Бонус (0.2 балла)**
#
# Ваш любимый новогодний фильм/сериал/мультик/книга/музыка/развление/ч-т-о-у-г-о-д-н-о
#
# Всем мандаринок!&#127818;

# %% [markdown]
# #### Ваш ответ здесь╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# Фильм - Ёлки10000000000000 (ёлки палки). Песня - в лесу родилась ёлочка. (Задания с деревьями, ответы такие же - деревянные).\
# Ну а если серьёзно, развлечение - в не совсем трезвом состоянии танцевать под Верку Сердючку.
